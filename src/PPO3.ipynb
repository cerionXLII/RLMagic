# %%
import os
import random
import time
from distutils.util import strtobool

#import gym
from ScheduleGym import ScheduleGym
import gymnasium as gym
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.distributions.categorical import Categorical
from torch.utils.tensorboard import SummaryWriter

from pathlib import Path
import datetime
import tempfile
import json
import shutil
import imageio
from types import SimpleNamespace

# %%
def parse_args():
    # fmt: off
    args = SimpleNamespace()
    args.exp_name = "ScheduleTester_with_add_remove"
    args.seed = 1
    args.torch_deterministic = True
    args.cuda = True
    args.track = False

    args.capture_video = False
    #args.env_id = "CartPole-v1"
    #args.env_id = "LunarLander-v2"
    args.env_id = "ScheduleGym-v0"
    args.capture_video = False

    args.total_timesteps = 50000*2*100*4
    args.learning_rate = 2.5e-4
    args.num_envs = 16
    #args.num_steps = 128
    args.num_steps = 256
    args.anneal_lr = True
    args.gae = True
    args.gamma = 0.99
    args.gae_lambda = 0.95
    args.num_minibatches = 4
    args.update_epochs = 4
    args.norm_adv = True

    args.clip_range = 0.2
    args.clip_vloss = True
    args.clip_coef = 0.2
    args.ent_coef = 0.01
    args.vf_coef = 0.5
    args.max_grad_norm = 0.5
    args.target_kl = None
    args.clip_range_vf = None


    args.batch_size = int(args.num_envs * args.num_steps)
    args.minibatch_size = int(args.batch_size // args.num_minibatches)
    # fmt: on
    return args

# %%
args = parse_args()
args
# Out:
# namespace(exp_name='ScheduleTester_with_add_remove',
#           seed=1,
#           torch_deterministic=True,
#           cuda=True,
#           track=False,
#           capture_video=False,
#           env_id='ScheduleGym-v0',
#           total_timesteps=40000000,
#           learning_rate=0.00025,
#           num_envs=16,
#           num_steps=256,
#           anneal_lr=True,
#           gae=True,
#           gamma=0.99,
#           gae_lambda=0.95,
#           num_minibatches=4,
#           update_epochs=4,
#           norm_adv=True,
#           clip_range=0.2,
#           clip_vloss=True,
#           clip_coef=0.2,
#           ent_coef=0.01,
#           vf_coef=0.5,
#           max_grad_norm=0.5,
#           target_kl=None,
#           clip_range_vf=None,
#           batch_size=4096,
#           minibatch_size=1024)

# %%
def layer_init(layer, std=np.sqrt(2), bias_const=0.0):
    torch.nn.init.orthogonal_(layer.weight, std)
    torch.nn.init.constant_(layer.bias, bias_const)
    return layer


class Agent(nn.Module):
    def __init__(self, state_size, action_sizes, hidden_dim=256):
        super().__init__()

        self.action_sizes = action_sizes
        self.state_size = state_size

        self.shared = nn.Sequential(
            layer_init(nn.Linear(state_size, hidden_dim)),
            nn.ReLU(),
            layer_init(nn.Linear(hidden_dim, hidden_dim)),
            nn.ReLU()
        )

        self.actor_heads = nn.ModuleList([layer_init(nn.Linear(hidden_dim, dim), std=0.01) for dim in action_sizes])


        self.critic = nn.Sequential(
            layer_init(nn.Linear(hidden_dim, hidden_dim)),
            nn.ReLU(),
            layer_init(nn.Linear(hidden_dim, 1), std=1.0)
        )
        

    def get_value(self, x):
        x = self.shared(x)
        return self.critic(x)

    def get_action_and_value(self, x, action=None):
        # x: (batch_size, state_size)
        x = self.shared(x) # (batch_size, hidden_dim)
        action_logits = [head(x) for head in self.actor_heads] # [(batch_size, action_size) for action_size in action_sizes]
        action_probs = [Categorical(logits=logits) for logits in action_logits] 
        if action is None:
            #action = torch.stack([probs.sample() for probs in action_probs], device=x.device)
            action = torch.stack([probs.sample() for probs in action_probs]).T # (batch_size, len(action_sizes))

        log_prob_sum = torch.stack([probs.log_prob(a) for probs, a in zip(action_probs, action.T)]).sum(dim=0) # (batch_size,)
        entropy_sum = torch.stack([probs.entropy() for probs in action_probs]).sum(dim=0) # (batch_size,)
        return action, log_prob_sum, entropy_sum, self.critic(x)

# %%
args = parse_args()
run_name = f"{args.env_id}__{args.exp_name}__{args.seed}__{int(time.time())}"
random.seed(args.seed)
np.random.seed(args.seed)
torch.manual_seed(args.seed)
torch.backends.cudnn.deterministic = args.torch_deterministic

device = torch.device("cuda" if torch.cuda.is_available() and args.cuda else "cpu")
print(f'Device: {device}')
# Out:
# Device: cuda

# %%
# env setup
# envs = gym.vector.SyncVectorEnv(
#     [make_env(args.env_id, args.seed + i, i, args.capture_video, run_name) for i in range(args.num_envs)]
# )

# %%
# envs = gym.vector.AsyncVectorEnv(
#     [make_env(args.env_id, args.seed + i, i, args.capture_video, run_name) for i in range(args.num_envs)]
# )

# %%
envs = gym.vector.AsyncVectorEnv(
    [lambda: ScheduleGym(num_days=2, num_hours=4, num_classes=1, num_subjects=2) for i in range(args.num_envs)]
)

# %%
state_dim = envs.single_observation_space.shape[0] 
state_dim
# Out:
# 10

# %%
action_dims = [dim.n for dim in envs.single_action_space]
action_dims
# Out:
# [2, 1, 2, 4, 2]

# %%
#override
#device =torch.device('cpu')

# %%
agent = Agent(state_size=state_dim, action_sizes=action_dims, hidden_dim=256).to(device)
optimizer = optim.Adam(agent.parameters(), lr=args.learning_rate, eps=1e-5)

# %%
x, _, = envs.reset()

# %%
x.shape
# Out:
# (16, 10)

# %%
ost = agent.get_value(torch.tensor(x, device=device, dtype=torch.float32))

# %%
ost
# Out:
# tensor([[-0.0004],
#         [ 0.0025],
#         [-0.0021],
#         [-0.0028],
#         [-0.0008],
#         [-0.0021],
#         [-0.0028],
#         [ 0.0014],
#         [ 0.0022],
#         [ 0.0003],
#         [ 0.0002],
#         [ 0.0013],
#         [ 0.0016],
#         [ 0.0003],
#         [-0.0021],
#         [ 0.0025]], device='cuda:0', grad_fn=<AddmmBackward0>)

# %%
action, log_prob_sum, entropy_sum, critic_value= agent.get_action_and_value(torch.tensor(x, device=device, dtype=torch.float32))

# %%
critic_value
# Out:
# tensor([[-0.0004],
#         [ 0.0025],
#         [-0.0021],
#         [-0.0028],
#         [-0.0008],
#         [-0.0021],
#         [-0.0028],
#         [ 0.0014],
#         [ 0.0022],
#         [ 0.0003],
#         [ 0.0002],
#         [ 0.0013],
#         [ 0.0016],
#         [ 0.0003],
#         [-0.0021],
#         [ 0.0025]], device='cuda:0', grad_fn=<AddmmBackward0>)

# %%
# ALGO Logic: Storage setup
obs = torch.zeros((args.num_steps, args.num_envs) + envs.single_observation_space.shape).to(device)
actions = torch.zeros((args.num_steps, args.num_envs) + envs.single_action_space.shape).to(device)
logprobs = torch.zeros((args.num_steps, args.num_envs)).to(device)
rewards = torch.zeros((args.num_steps, args.num_envs)).to(device)
dones = torch.zeros((args.num_steps, args.num_envs)).to(device)
values = torch.zeros((args.num_steps, args.num_envs)).to(device)

# %%
global_step = 0
start_time = time.time()
next_obs, _ = envs.reset()
next_obs = torch.Tensor(next_obs).to(device)
next_done = torch.zeros(args.num_envs).to(device)
num_updates = args.total_timesteps // args.batch_size
print(f'Num updates: {num_updates}')
print(f'Run Name: {run_name}')
# Out:
# Num updates: 9765
# Run Name: ScheduleGym-v0__ScheduleTester_with_add_remove__1__1723711213

# %%
writer = SummaryWriter(f"runs/{run_name}")
writer.add_text(
    "hyperparameters",
    "|param|value|\n|-|-|\n%s" % ("\n".join([f"|{key}|{value}|" for key, value in vars(args).items()])),
)

# %%
for update in range(1, num_updates + 1):
    # Annealing the rate if instructed to do so.
    if args.anneal_lr:
        frac = 1.0 - (update - 1.0) / num_updates
        lrnow = frac * args.learning_rate
        optimizer.param_groups[0]["lr"] = lrnow

    for step in range(0, args.num_steps):
        global_step += 1 * args.num_envs
        obs[step] = next_obs
        dones[step] = next_done

        # ALGO LOGIC: action logic
        with torch.no_grad():
            action, logprob, _, value = agent.get_action_and_value(next_obs)
            values[step] = value.flatten()
        actions[step] = action
        logprobs[step] = logprob

       
        next_obs, reward, done, info, _ = envs.step(action.cpu().numpy())
        rewards[step] = torch.tensor(reward).to(device).view(-1)
        next_obs, next_done = torch.Tensor(next_obs).to(device), torch.Tensor(done).to(device)

        # for item in info:
        #     if "episode" in item.keys():
        #         print(f"global_step={global_step}, episodic_return={item['episode']['r']}")
        #         writer.add_scalar("charts/episodic_return", item["episode"]["r"], global_step)
        #         writer.add_scalar("charts/episodic_length", item["episode"]["l"], global_step)
        #         break

    # bootstrap value if not done
    with torch.no_grad():
        next_value = agent.get_value(next_obs).reshape(1, -1)
        if args.gae:
            advantages = torch.zeros_like(rewards).to(device)
            lastgaelam = 0
            for t in reversed(range(args.num_steps)):
                if t == args.num_steps - 1:
                    nextnonterminal = 1.0 - next_done
                    nextvalues = next_value
                else:
                    nextnonterminal = 1.0 - dones[t + 1]
                    nextvalues = values[t + 1]
                delta = rewards[t] + args.gamma * nextvalues * nextnonterminal - values[t]
                advantages[t] = lastgaelam = delta + args.gamma * args.gae_lambda * nextnonterminal * lastgaelam
            returns = advantages + values
        else:
            returns = torch.zeros_like(rewards).to(device)
            for t in reversed(range(args.num_steps)):
                if t == args.num_steps - 1:
                    nextnonterminal = 1.0 - next_done
                    next_return = next_value
                else:
                    nextnonterminal = 1.0 - dones[t + 1]
                    next_return = returns[t + 1]
                returns[t] = rewards[t] + args.gamma * nextnonterminal * next_return
            advantages = returns - values

    # flatten the batch
    b_obs = obs.reshape((-1,) + envs.single_observation_space.shape)
    b_logprobs = logprobs.reshape(-1)
    b_actions = actions.reshape((-1,) + envs.single_action_space.shape)
    b_advantages = advantages.reshape(-1)
    b_returns = returns.reshape(-1)
    b_values = values.reshape(-1)

    # Optimizing the policy and value network
    b_inds = np.arange(args.batch_size)
    clipfracs = []
    for epoch in range(args.update_epochs):
        np.random.shuffle(b_inds)
        for start in range(0, args.batch_size, args.minibatch_size):
            end = start + args.minibatch_size
            mb_inds = b_inds[start:end]

            _, newlogprob, entropy, newvalue = agent.get_action_and_value(b_obs[mb_inds], b_actions.long()[mb_inds])
            logratio = newlogprob - b_logprobs[mb_inds]
            ratio = logratio.exp()

            with torch.no_grad():
                # calculate approx_kl http://joschu.net/blog/kl-approx.html
                old_approx_kl = (-logratio).mean()
                approx_kl = ((ratio - 1) - logratio).mean()
                clipfracs += [((ratio - 1.0).abs() > args.clip_coef).float().mean().item()]

            mb_advantages = b_advantages[mb_inds]
            if args.norm_adv:
                mb_advantages = (mb_advantages - mb_advantages.mean()) / (mb_advantages.std() + 1e-8)

            # Policy loss
            pg_loss1 = -mb_advantages * ratio
            pg_loss2 = -mb_advantages * torch.clamp(ratio, 1 - args.clip_coef, 1 + args.clip_coef)
            pg_loss = torch.max(pg_loss1, pg_loss2).mean()

            # Value loss
            newvalue = newvalue.view(-1)
            if args.clip_vloss:
                v_loss_unclipped = (newvalue - b_returns[mb_inds]) ** 2
                v_clipped = b_values[mb_inds] + torch.clamp(
                    newvalue - b_values[mb_inds],
                    -args.clip_coef,
                    args.clip_coef,
                )
                v_loss_clipped = (v_clipped - b_returns[mb_inds]) ** 2
                v_loss_max = torch.max(v_loss_unclipped, v_loss_clipped)
                v_loss = 0.5 * v_loss_max.mean()
            else:
                v_loss = 0.5 * ((newvalue - b_returns[mb_inds]) ** 2).mean()

            entropy_loss = entropy.mean()
            loss = pg_loss - args.ent_coef * entropy_loss + v_loss * args.vf_coef

            optimizer.zero_grad()
            loss.backward()
            nn.utils.clip_grad_norm_(agent.parameters(), args.max_grad_norm)
            optimizer.step()

        if args.target_kl is not None:
            if approx_kl > args.target_kl:
                break

    y_pred, y_true = b_values.cpu().numpy(), b_returns.cpu().numpy()
    var_y = np.var(y_true)
    explained_var = np.nan if var_y == 0 else 1 - np.var(y_true - y_pred) / var_y

    #record rewards for plotting purposes
    writer.add_scalar("charts/learning_rate", optimizer.param_groups[0]["lr"], global_step)
    writer.add_scalar("charts/value_loss", v_loss.item(), global_step)
    writer.add_scalar("charts/policy_loss", pg_loss.item(), global_step)
    writer.add_scalar("charts/entropy", entropy_loss.item(), global_step)
    writer.add_scalar("charts/old_approx_kl", old_approx_kl.item(), global_step)
    writer.add_scalar("charts/approx_kl", approx_kl.item(), global_step)
    writer.add_scalar("charts/clipfrac", np.mean(clipfracs), global_step)
    writer.add_scalar("charts/explained_variance", explained_var, global_step)
    writer.add_scalar("charts/SPS", int(global_step / (time.time() - start_time)), global_step)
    writer.add_scalar("charts/rewards", rewards.mean().item(), global_step)

    if update % 10 == 0:
        print(f"update: {update}/ {num_updates} Max reward: {rewards.max().item()} Min reward: {rewards.min().item()} Mean reward: {rewards.mean().item()}")
# Out:
# update: 10/ 9765 Max reward: 74.9000015258789 Min reward: -2.25 Mean reward: 0.18951421976089478
# update: 20/ 9765 Max reward: 77.75 Min reward: -2.25 Mean reward: 0.4688721299171448
# update: 30/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.7583374381065369
# update: 40/ 9765 Max reward: 74.05000305175781 Min reward: -2.25 Mean reward: 0.6122437119483948
# update: 50/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.7146363258361816
# update: 60/ 9765 Max reward: 76.75 Min reward: -2.25 Mean reward: 0.7876466512680054
# update: 70/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.6830933690071106
# update: 80/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 0.6647461652755737
# update: 90/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.6976197361946106
# update: 100/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.7762573957443237
# update: 110/ 9765 Max reward: 79.05000305175781 Min reward: -2.25 Mean reward: 0.6089966297149658
# update: 120/ 9765 Max reward: 75.9000015258789 Min reward: -2.25 Mean reward: 0.6604371070861816
# update: 130/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 0.7657349109649658
# update: 140/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 0.6509888172149658
# update: 150/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.7503174543380737
# update: 160/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.7431519627571106
# update: 170/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8607788681983948
# update: 180/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8183106184005737
# update: 190/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 0.6883301734924316
# update: 200/ 9765 Max reward: 75.9000015258789 Min reward: -2.25 Mean reward: 0.8545167446136475
# update: 210/ 9765 Max reward: 78.9000015258789 Min reward: -2.25 Mean reward: 0.7027222514152527
# update: 220/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8866822123527527
# update: 230/ 9765 Max reward: 76.5999984741211 Min reward: -2.25 Mean reward: 0.9576416611671448
# update: 240/ 9765 Max reward: 78.5999984741211 Min reward: -2.25 Mean reward: 0.8652100563049316
# update: 250/ 9765 Max reward: 75.9000015258789 Min reward: -2.25 Mean reward: 0.6963013410568237
# update: 260/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 0.8507081270217896
# update: 270/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.7547364234924316
# update: 280/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9329590797424316
# update: 290/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.7604614496231079
# update: 300/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.7754395604133606
# update: 310/ 9765 Max reward: 76.75 Min reward: -2.25 Mean reward: 0.7119873762130737
# update: 320/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8170166611671448
# update: 330/ 9765 Max reward: 76.75 Min reward: -2.25 Mean reward: 0.7165039777755737
# update: 340/ 9765 Max reward: 75.9000015258789 Min reward: -2.25 Mean reward: 0.7243775129318237
# update: 350/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.7486939430236816
# update: 360/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.9693481922149658
# update: 370/ 9765 Max reward: 76.75 Min reward: -2.25 Mean reward: 0.8957764506340027
# update: 380/ 9765 Max reward: 77.75 Min reward: -2.25 Mean reward: 0.6141724586486816
# update: 390/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 0.9277222156524658
# update: 400/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 0.8296265602111816
# update: 410/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8912354111671448
# update: 420/ 9765 Max reward: 74.9000015258789 Min reward: -2.25 Mean reward: 0.8123657703399658
# update: 430/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 0.8866577744483948
# update: 440/ 9765 Max reward: 75.9000015258789 Min reward: -2.25 Mean reward: 0.5394775867462158
# update: 450/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.9180908799171448
# update: 460/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 0.7220337390899658
# update: 470/ 9765 Max reward: 75.9000015258789 Min reward: -2.25 Mean reward: 0.7607910633087158
# update: 480/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 0.9424073100090027
# update: 490/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8098389506340027
# update: 500/ 9765 Max reward: 77.5999984741211 Min reward: -2.25 Mean reward: 0.6475709080696106
# update: 510/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.6929810643196106
# update: 520/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8299072980880737
# update: 530/ 9765 Max reward: 75.75 Min reward: -2.25 Mean reward: 0.8526002168655396
# update: 540/ 9765 Max reward: 78.9000015258789 Min reward: -2.25 Mean reward: 0.6907471418380737
# update: 550/ 9765 Max reward: 78.9000015258789 Min reward: -2.25 Mean reward: 0.6052124500274658
# update: 560/ 9765 Max reward: 75.9000015258789 Min reward: -2.25 Mean reward: 0.87603759765625
# update: 570/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9052368402481079
# update: 580/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.7932130098342896
# update: 590/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9360962510108948
# update: 600/ 9765 Max reward: 76.75 Min reward: -2.25 Mean reward: 0.8030640482902527
# update: 610/ 9765 Max reward: 74.9000015258789 Min reward: -2.25 Mean reward: 0.9748901724815369
# update: 620/ 9765 Max reward: 75.9000015258789 Min reward: -2.25 Mean reward: 0.7556763291358948
# update: 630/ 9765 Max reward: 76.75 Min reward: -2.25 Mean reward: 1.2792847156524658
# update: 640/ 9765 Max reward: 75.5999984741211 Min reward: -2.25 Mean reward: 0.6392334699630737
# update: 650/ 9765 Max reward: 76.75 Min reward: -2.25 Mean reward: 0.7635743021965027
# update: 660/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.7327027320861816
# update: 670/ 9765 Max reward: 77.5999984741211 Min reward: -2.25 Mean reward: 0.7149292230606079
# update: 680/ 9765 Max reward: 75.5999984741211 Min reward: -2.25 Mean reward: 0.8180786371231079
# update: 690/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8255249261856079
# update: 700/ 9765 Max reward: 76.05000305175781 Min reward: -2.25 Mean reward: 0.8947387933731079
# update: 710/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.6220215559005737
# update: 720/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.9262452125549316
# update: 730/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9745483994483948
# update: 740/ 9765 Max reward: 76.5999984741211 Min reward: -2.25 Mean reward: 0.6239869594573975
# update: 750/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8554443717002869
# update: 760/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8282227516174316
# update: 770/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 0.8046509027481079
# update: 780/ 9765 Max reward: 77.05000305175781 Min reward: -2.25 Mean reward: 1.0340332984924316
# update: 790/ 9765 Max reward: 77.75 Min reward: -2.25 Mean reward: 0.8020874261856079
# update: 800/ 9765 Max reward: 75.9000015258789 Min reward: -2.25 Mean reward: 0.9307007789611816
# update: 810/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.5414551496505737
# update: 820/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.9387085437774658
# update: 830/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.7103517055511475
# update: 840/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.0204224586486816
# update: 850/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.0126099586486816
# update: 860/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 1.0727295875549316
# update: 870/ 9765 Max reward: 78.5999984741211 Min reward: -2.25 Mean reward: 0.7919312119483948
# update: 880/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.7420288920402527
# update: 890/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.9262452125549316
# update: 900/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.66522216796875
# update: 910/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.8172608017921448
# update: 920/ 9765 Max reward: 77.5999984741211 Min reward: -2.25 Mean reward: 0.9144531488418579
# update: 930/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9408569931983948
# update: 940/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.0145996809005737
# update: 950/ 9765 Max reward: 78.75 Min reward: -2.25 Mean reward: 1.1288819313049316
# update: 960/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.7977906465530396
# update: 970/ 9765 Max reward: 76.05000305175781 Min reward: -2.25 Mean reward: 0.8293823599815369
# update: 980/ 9765 Max reward: 77.5999984741211 Min reward: -2.25 Mean reward: 0.7768555879592896
# update: 990/ 9765 Max reward: 76.75 Min reward: -2.25 Mean reward: 0.7657837867736816
# update: 1000/ 9765 Max reward: 77.75 Min reward: -2.25 Mean reward: 0.8533082008361816
# update: 1010/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.6184082627296448
# update: 1020/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.9566773772239685
# update: 1030/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 0.8494629859924316
# update: 1040/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.0194580554962158
# update: 1050/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.7574951648712158
# update: 1060/ 9765 Max reward: 75.9000015258789 Min reward: -2.25 Mean reward: 0.6127563714981079
# update: 1070/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 0.6679565906524658
# update: 1080/ 9765 Max reward: 77.75 Min reward: -2.25 Mean reward: 0.8266845941543579
# update: 1090/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 0.7838135361671448
# update: 1100/ 9765 Max reward: 76.44999694824219 Min reward: -2.25 Mean reward: 0.8386719226837158
# update: 1110/ 9765 Max reward: 77.05000305175781 Min reward: -2.25 Mean reward: 0.8194092512130737
# update: 1120/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8141724467277527
# update: 1130/ 9765 Max reward: 78.9000015258789 Min reward: -2.25 Mean reward: 0.6829224824905396
# update: 1140/ 9765 Max reward: 78.9000015258789 Min reward: -2.25 Mean reward: 0.8908692598342896
# update: 1150/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9964966177940369
# update: 1160/ 9765 Max reward: 76.5999984741211 Min reward: -2.25 Mean reward: 0.7757568955421448
# update: 1170/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.9326660633087158
# update: 1180/ 9765 Max reward: 76.44999694824219 Min reward: -2.25 Mean reward: 0.7796632051467896
# update: 1190/ 9765 Max reward: 75.05000305175781 Min reward: -2.25 Mean reward: 0.7759888172149658
# update: 1200/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8727173805236816
# update: 1210/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9430542588233948
# update: 1220/ 9765 Max reward: 77.5999984741211 Min reward: -2.25 Mean reward: 0.6972656846046448
# update: 1230/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9344848990440369
# update: 1240/ 9765 Max reward: 75.9000015258789 Min reward: -2.25 Mean reward: 0.7956299185752869
# update: 1250/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8169800043106079
# update: 1260/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.9966309070587158
# update: 1270/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8857910633087158
# update: 1280/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.0758057832717896
# update: 1290/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 0.6852905750274658
# update: 1300/ 9765 Max reward: 77.5999984741211 Min reward: -2.25 Mean reward: 0.8415894508361816
# update: 1310/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9843384623527527
# update: 1320/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8674927949905396
# update: 1330/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9885254502296448
# update: 1340/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.8246338367462158
# update: 1350/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8429688215255737
# update: 1360/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 1.0811158418655396
# update: 1370/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.6889526844024658
# update: 1380/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9706666469573975
# update: 1390/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.7641602754592896
# update: 1400/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.7617676258087158
# update: 1410/ 9765 Max reward: 75.9000015258789 Min reward: -2.25 Mean reward: 0.9415527582168579
# update: 1420/ 9765 Max reward: 77.5999984741211 Min reward: -2.25 Mean reward: 0.9331910014152527
# update: 1430/ 9765 Max reward: 76.5999984741211 Min reward: -2.25 Mean reward: 0.9864380955696106
# update: 1440/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8821533918380737
# update: 1450/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.0189697742462158
# update: 1460/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.9376709461212158
# update: 1470/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8397827744483948
# update: 1480/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.9039551019668579
# update: 1490/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8896607160568237
# update: 1500/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9236450791358948
# update: 1510/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8822267055511475
# update: 1520/ 9765 Max reward: 77.75 Min reward: -2.25 Mean reward: 0.8141968250274658
# update: 1530/ 9765 Max reward: 78.9000015258789 Min reward: -2.25 Mean reward: 0.7171387672424316
# update: 1540/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.0596923828125
# update: 1550/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8401612043380737
# update: 1560/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.9057861566543579
# update: 1570/ 9765 Max reward: 76.5999984741211 Min reward: -2.25 Mean reward: 0.8453247547149658
# update: 1580/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.7267212271690369
# update: 1590/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.6120362281799316
# update: 1600/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.7507324814796448
# update: 1610/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.0967285633087158
# update: 1620/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8607910871505737
# update: 1630/ 9765 Max reward: 76.75 Min reward: -2.25 Mean reward: 0.9270020127296448
# update: 1640/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.8744140863418579
# update: 1650/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.6972534656524658
# update: 1660/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9815796613693237
# update: 1670/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.0775269269943237
# update: 1680/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8936890363693237
# update: 1690/ 9765 Max reward: 76.75 Min reward: -2.25 Mean reward: 0.836535632610321
# update: 1700/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8277711272239685
# update: 1710/ 9765 Max reward: 79.05000305175781 Min reward: -2.25 Mean reward: 0.9659424424171448
# update: 1720/ 9765 Max reward: 74.9000015258789 Min reward: -2.25 Mean reward: 0.8172851800918579
# update: 1730/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.0176148414611816
# update: 1740/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.6872925162315369
# update: 1750/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.6157838106155396
# update: 1760/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.9201782941818237
# update: 1770/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9221192002296448
# update: 1780/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 0.7500733137130737
# update: 1790/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8430176973342896
# update: 1800/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9560669660568237
# update: 1810/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8667725324630737
# update: 1820/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.1293702125549316
# update: 1830/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.7891602516174316
# update: 1840/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.0152710676193237
# update: 1850/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.7831299304962158
# update: 1860/ 9765 Max reward: 78.9000015258789 Min reward: -2.25 Mean reward: 0.7743164300918579
# update: 1870/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.7761842012405396
# update: 1880/ 9765 Max reward: 77.05000305175781 Min reward: -2.25 Mean reward: 0.8390259742736816
# update: 1890/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8862549662590027
# update: 1900/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 0.8296143412590027
# update: 1910/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.7449707984924316
# update: 1920/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8649414777755737
# update: 1930/ 9765 Max reward: 77.5999984741211 Min reward: -2.25 Mean reward: 0.9561036229133606
# update: 1940/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9269165992736816
# update: 1950/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9530152082443237
# update: 1960/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 0.9039307832717896
# update: 1970/ 9765 Max reward: 75.75 Min reward: -2.25 Mean reward: 0.8863648772239685
# update: 1980/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.9344117045402527
# update: 1990/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.6441894769668579
# update: 2000/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8156372904777527
# update: 2010/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.9303467869758606
# update: 2020/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8561524152755737
# update: 2030/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.0385864973068237
# update: 2040/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8443360328674316
# update: 2050/ 9765 Max reward: 77.05000305175781 Min reward: -2.25 Mean reward: 0.9618653059005737
# update: 2060/ 9765 Max reward: 75.9000015258789 Min reward: -2.25 Mean reward: 0.8537354469299316
# update: 2070/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.0475099086761475
# update: 2080/ 9765 Max reward: 78.9000015258789 Min reward: -2.25 Mean reward: 0.9381470680236816
# update: 2090/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 0.8686035871505737
# update: 2100/ 9765 Max reward: 76.75 Min reward: -2.25 Mean reward: 0.8162598609924316
# update: 2110/ 9765 Max reward: 76.5999984741211 Min reward: -2.25 Mean reward: 0.9569947123527527
# update: 2120/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.7178101539611816
# update: 2130/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.0304322242736816
# update: 2140/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 0.7658448219299316
# update: 2150/ 9765 Max reward: 77.44999694824219 Min reward: -2.25 Mean reward: 0.9058350920677185
# update: 2160/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9509766101837158
# update: 2170/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.7011475563049316
# update: 2180/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.3730469942092896
# update: 2190/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 0.8768189549446106
# update: 2200/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.7282837629318237
# update: 2210/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.9889649152755737
# update: 2220/ 9765 Max reward: 77.5999984741211 Min reward: -2.25 Mean reward: 0.8813110589981079
# update: 2230/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.75469970703125
# update: 2240/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.7736695408821106
# update: 2250/ 9765 Max reward: 76.75 Min reward: -2.25 Mean reward: 0.9444824457168579
# update: 2260/ 9765 Max reward: 77.75 Min reward: -2.25 Mean reward: 1.2305665016174316
# update: 2270/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9245972633361816
# update: 2280/ 9765 Max reward: 77.5999984741211 Min reward: -2.25 Mean reward: 1.1588501930236816
# update: 2290/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.9090088605880737
# update: 2300/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.7425659894943237
# update: 2310/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.0682374238967896
# update: 2320/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8930542469024658
# update: 2330/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 1.0468872785568237
# update: 2340/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.9256592392921448
# update: 2350/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9585938453674316
# update: 2360/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 0.9939087629318237
# update: 2370/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.8337647318840027
# update: 2380/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.1453614234924316
# update: 2390/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9898194074630737
# update: 2400/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 0.8880738019943237
# update: 2410/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9351929426193237
# update: 2420/ 9765 Max reward: 77.44999694824219 Min reward: -2.25 Mean reward: 0.9267700910568237
# update: 2430/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8461182117462158
# update: 2440/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 0.6964600086212158
# update: 2450/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.7769653797149658
# update: 2460/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8531616926193237
# update: 2470/ 9765 Max reward: 76.75 Min reward: -2.25 Mean reward: 0.8590699434280396
# update: 2480/ 9765 Max reward: 76.75 Min reward: -2.25 Mean reward: 0.9513428211212158
# update: 2490/ 9765 Max reward: 76.75 Min reward: -2.25 Mean reward: 1.2076172828674316
# update: 2500/ 9765 Max reward: 78.9000015258789 Min reward: -2.25 Mean reward: 0.9536743760108948
# update: 2510/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.1529297828674316
# update: 2520/ 9765 Max reward: 76.75 Min reward: -2.25 Mean reward: 0.8304932117462158
# update: 2530/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.1217774152755737
# update: 2540/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.9541016817092896
# update: 2550/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.14910888671875
# update: 2560/ 9765 Max reward: 79.05000305175781 Min reward: -2.25 Mean reward: 1.0413819551467896
# update: 2570/ 9765 Max reward: 76.75 Min reward: -2.25 Mean reward: 0.8762086033821106
# update: 2580/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.0674805641174316
# update: 2590/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.0381226539611816
# update: 2600/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.0410034656524658
# update: 2610/ 9765 Max reward: 78.75 Min reward: -2.25 Mean reward: 0.8873291611671448
# update: 2620/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.9081299304962158
# update: 2630/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.7689698934555054
# update: 2640/ 9765 Max reward: 77.05000305175781 Min reward: -2.25 Mean reward: 0.8266845941543579
# update: 2650/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.1750489473342896
# update: 2660/ 9765 Max reward: 78.5999984741211 Min reward: -2.25 Mean reward: 0.9837281107902527
# update: 2670/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9105714559555054
# update: 2680/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 1.0755493640899658
# update: 2690/ 9765 Max reward: 75.9000015258789 Min reward: -2.25 Mean reward: 0.9106812477111816
# update: 2700/ 9765 Max reward: 78.9000015258789 Min reward: -2.25 Mean reward: 0.7509765625
# update: 2710/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.9689332246780396
# update: 2720/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.7442260980606079
# update: 2730/ 9765 Max reward: 77.05000305175781 Min reward: -2.25 Mean reward: 0.8781372308731079
# update: 2740/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 0.9322022199630737
# update: 2750/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8116822242736816
# update: 2760/ 9765 Max reward: 76.75 Min reward: -2.25 Mean reward: 1.056481957435608
# update: 2770/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8911255598068237
# update: 2780/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8488403558731079
# update: 2790/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 0.8972657918930054
# update: 2800/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.7844483256340027
# update: 2810/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8150879144668579
# update: 2820/ 9765 Max reward: 75.75 Min reward: -2.25 Mean reward: 0.7790162563323975
# update: 2830/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8310669660568237
# update: 2840/ 9765 Max reward: 77.05000305175781 Min reward: -2.25 Mean reward: 0.8282837867736816
# update: 2850/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.7401490211486816
# update: 2860/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.2507447004318237
# update: 2870/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9006592631340027
# update: 2880/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 0.9519532322883606
# update: 2890/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9827271103858948
# update: 2900/ 9765 Max reward: 76.05000305175781 Min reward: -2.25 Mean reward: 0.7206421494483948
# update: 2910/ 9765 Max reward: 77.75 Min reward: -2.25 Mean reward: 0.83514404296875
# update: 2920/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 1.11077880859375
# update: 2930/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8446167707443237
# update: 2940/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8231568336486816
# update: 2950/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8990967273712158
# update: 2960/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8147218227386475
# update: 2970/ 9765 Max reward: 78.9000015258789 Min reward: -2.25 Mean reward: 0.9961548447608948
# update: 2980/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.8346680402755737
# update: 2990/ 9765 Max reward: 76.44999694824219 Min reward: -2.25 Mean reward: 0.8970704078674316
# update: 3000/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.03411865234375
# update: 3010/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.0583375692367554
# update: 3020/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 0.9241578578948975
# update: 3030/ 9765 Max reward: 77.5999984741211 Min reward: -2.25 Mean reward: 0.7143189311027527
# update: 3040/ 9765 Max reward: 77.5999984741211 Min reward: -2.25 Mean reward: 0.8011109232902527
# update: 3050/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.9625611305236816
# update: 3060/ 9765 Max reward: 75.9000015258789 Min reward: -2.25 Mean reward: 1.060302734375
# update: 3070/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.9732910990715027
# update: 3080/ 9765 Max reward: 77.75 Min reward: -2.25 Mean reward: 0.9599976539611816
# update: 3090/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9402588605880737
# update: 3100/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.064355492591858
# update: 3110/ 9765 Max reward: 77.44999694824219 Min reward: -2.25 Mean reward: 0.9479370713233948
# update: 3120/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 0.7896851301193237
# update: 3130/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.9901123046875
# update: 3140/ 9765 Max reward: 78.5999984741211 Min reward: -2.25 Mean reward: 1.1151245832443237
# update: 3150/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.8257080912590027
# update: 3160/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9066773056983948
# update: 3170/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9006714820861816
# update: 3180/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9094117283821106
# update: 3190/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.0334718227386475
# update: 3200/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.0393189191818237
# update: 3210/ 9765 Max reward: 76.75 Min reward: -2.25 Mean reward: 0.9455689191818237
# update: 3220/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.0475831031799316
# update: 3230/ 9765 Max reward: 77.5999984741211 Min reward: -2.25 Mean reward: 0.9373902082443237
# update: 3240/ 9765 Max reward: 76.5999984741211 Min reward: -2.25 Mean reward: 1.0507690906524658
# update: 3250/ 9765 Max reward: 76.75 Min reward: -2.25 Mean reward: 0.7209961414337158
# update: 3260/ 9765 Max reward: 78.9000015258789 Min reward: -2.25 Mean reward: 1.1315553188323975
# update: 3270/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8413575291633606
# update: 3280/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8161866664886475
# update: 3290/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.02911376953125
# update: 3300/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8844971656799316
# update: 3310/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9527344107627869
# update: 3320/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.1154053211212158
# update: 3330/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.0521485805511475
# update: 3340/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9520019888877869
# update: 3350/ 9765 Max reward: 77.5999984741211 Min reward: -2.25 Mean reward: 0.9509766697883606
# update: 3360/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8455567359924316
# update: 3370/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 0.8803833723068237
# update: 3380/ 9765 Max reward: 78.75 Min reward: -2.25 Mean reward: 1.24365234375
# update: 3390/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.131494164466858
# update: 3400/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.9683838486671448
# update: 3410/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 0.9334839582443237
# update: 3420/ 9765 Max reward: 76.5999984741211 Min reward: -2.25 Mean reward: 0.84033203125
# update: 3430/ 9765 Max reward: 75.9000015258789 Min reward: -2.25 Mean reward: 0.9602051973342896
# update: 3440/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 1.0343506336212158
# update: 3450/ 9765 Max reward: 77.75 Min reward: -2.25 Mean reward: 0.9572021961212158
# update: 3460/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.9285645484924316
# update: 3470/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9829102754592896
# update: 3480/ 9765 Max reward: 77.5999984741211 Min reward: -2.25 Mean reward: 0.7944092750549316
# update: 3490/ 9765 Max reward: 77.75 Min reward: -2.25 Mean reward: 0.8468140363693237
# update: 3500/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 1.0460205078125
# update: 3510/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 0.8709107041358948
# update: 3520/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.7886719703674316
# update: 3530/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8213623762130737
# update: 3540/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8491822481155396
# update: 3550/ 9765 Max reward: 74.9000015258789 Min reward: -2.25 Mean reward: 0.7362183332443237
# update: 3560/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 0.81243896484375
# update: 3570/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 0.9608765840530396
# update: 3580/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8059082627296448
# update: 3590/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.0351197719573975
# update: 3600/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 1.0869873762130737
# update: 3610/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.0730347633361816
# update: 3620/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 1.0755006074905396
# update: 3630/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8802124857902527
# update: 3640/ 9765 Max reward: 77.75 Min reward: -2.25 Mean reward: 1.0095338821411133
# update: 3650/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.9141724109649658
# update: 3660/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 0.9593628644943237
# update: 3670/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9195435643196106
# update: 3680/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.9912232160568237
# update: 3690/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.6530640125274658
# update: 3700/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.0845093727111816
# update: 3710/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.2345582246780396
# update: 3720/ 9765 Max reward: 76.75 Min reward: -2.25 Mean reward: 0.7240478992462158
# update: 3730/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.0505006313323975
# update: 3740/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8309204578399658
# update: 3750/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.1268311738967896
# update: 3760/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9458740949630737
# update: 3770/ 9765 Max reward: 77.75 Min reward: -2.25 Mean reward: 0.8127319812774658
# update: 3780/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.9408081769943237
# update: 3790/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9420166611671448
# update: 3800/ 9765 Max reward: 77.44999694824219 Min reward: -2.25 Mean reward: 0.7677735090255737
# update: 3810/ 9765 Max reward: 77.05000305175781 Min reward: -2.25 Mean reward: 1.1112549304962158
# update: 3820/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.7009034156799316
# update: 3830/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.9440064430236816
# update: 3840/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.1427613496780396
# update: 3850/ 9765 Max reward: 75.9000015258789 Min reward: -2.25 Mean reward: 0.9584107398986816
# update: 3860/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 0.7345459461212158
# update: 3870/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9223634004592896
# update: 3880/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.2243164777755737
# update: 3890/ 9765 Max reward: 77.5999984741211 Min reward: -2.25 Mean reward: 0.9714233875274658
# update: 3900/ 9765 Max reward: 77.75 Min reward: -2.25 Mean reward: 1.09674072265625
# update: 3910/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.7741944193840027
# update: 3920/ 9765 Max reward: 78.75 Min reward: -2.25 Mean reward: 1.0450562238693237
# update: 3930/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.9388917088508606
# update: 3940/ 9765 Max reward: 77.75 Min reward: -2.25 Mean reward: 1.2115845680236816
# update: 3950/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.9036865234375
# update: 3960/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9634033441543579
# update: 3970/ 9765 Max reward: 77.5999984741211 Min reward: -2.25 Mean reward: 0.98095703125
# update: 3980/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.9629395008087158
# update: 3990/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.7742554545402527
# update: 4000/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.7746094465255737
# update: 4010/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.20745849609375
# update: 4020/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.7732422351837158
# update: 4030/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.0442261695861816
# update: 4040/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8619385361671448
# update: 4050/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.2338745594024658
# update: 4060/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.9182617664337158
# update: 4070/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.11810302734375
# update: 4080/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.1113770008087158
# update: 4090/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.3534302711486816
# update: 4100/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.2929688692092896
# update: 4110/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9713623523712158
# update: 4120/ 9765 Max reward: 77.44999694824219 Min reward: -2.25 Mean reward: 0.7738891839981079
# update: 4130/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.1158570051193237
# update: 4140/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 0.8910156488418579
# update: 4150/ 9765 Max reward: 76.75 Min reward: -2.25 Mean reward: 1.0126588344573975
# update: 4160/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9350464344024658
# update: 4170/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.1585205793380737
# update: 4180/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 0.8322144150733948
# update: 4190/ 9765 Max reward: 75.75 Min reward: -2.25 Mean reward: 1.12896728515625
# update: 4200/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.1232788562774658
# update: 4210/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.072045922279358
# update: 4220/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 1.1245850324630737
# update: 4230/ 9765 Max reward: 78.75 Min reward: -2.25 Mean reward: 0.9514038562774658
# update: 4240/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 1.1372193098068237
# update: 4250/ 9765 Max reward: 75.05000305175781 Min reward: -2.25 Mean reward: 0.8994263410568237
# update: 4260/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.0484743118286133
# update: 4270/ 9765 Max reward: 78.9000015258789 Min reward: -2.25 Mean reward: 1.0493409633636475
# update: 4280/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.0117554664611816
# update: 4290/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.0000977516174316
# update: 4300/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 1.0125854015350342
# update: 4310/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 0.7478394508361816
# update: 4320/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9760620594024658
# update: 4330/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 0.9073853492736816
# update: 4340/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.9184204936027527
# update: 4350/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.6999146342277527
# update: 4360/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9833862781524658
# update: 4370/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 1.0983033180236816
# update: 4380/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 1.1202638149261475
# update: 4390/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 1.0966553688049316
# update: 4400/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.0231934785842896
# update: 4410/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.992138683795929
# update: 4420/ 9765 Max reward: 76.5999984741211 Min reward: -2.25 Mean reward: 1.1753907203674316
# update: 4430/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8730225563049316
# update: 4440/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.0812500715255737
# update: 4450/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 0.8519654273986816
# update: 4460/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 1.0637695789337158
# update: 4470/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 1.1961183547973633
# update: 4480/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.1022460460662842
# update: 4490/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.0987305641174316
# update: 4500/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8623780012130737
# update: 4510/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.1353394985198975
# update: 4520/ 9765 Max reward: 78.5999984741211 Min reward: -2.25 Mean reward: 1.1182861328125
# update: 4530/ 9765 Max reward: 77.05000305175781 Min reward: -2.25 Mean reward: 1.1860229969024658
# update: 4540/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8401489853858948
# update: 4550/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.8230713605880737
# update: 4560/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.0694947242736816
# update: 4570/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.1648560762405396
# update: 4580/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.0995850563049316
# update: 4590/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.4134032726287842
# update: 4600/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.1285889148712158
# update: 4610/ 9765 Max reward: 77.5999984741211 Min reward: -2.25 Mean reward: 1.0887939929962158
# update: 4620/ 9765 Max reward: 76.75 Min reward: -2.25 Mean reward: 0.9696289896965027
# update: 4630/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.0774171352386475
# update: 4640/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9704468250274658
# update: 4650/ 9765 Max reward: 76.75 Min reward: -2.25 Mean reward: 0.8451294302940369
# update: 4660/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 0.9662353992462158
# update: 4670/ 9765 Max reward: 77.44999694824219 Min reward: -2.25 Mean reward: 1.0492920875549316
# update: 4680/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.1188477277755737
# update: 4690/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.09197998046875
# update: 4700/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.934814453125
# update: 4710/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.9803101420402527
# update: 4720/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 0.6850098371505737
# update: 4730/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9445313215255737
# update: 4740/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.1876953840255737
# update: 4750/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.0168213844299316
# update: 4760/ 9765 Max reward: 76.05000305175781 Min reward: -2.25 Mean reward: 0.9431275129318237
# update: 4770/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.0344727039337158
# update: 4780/ 9765 Max reward: 77.44999694824219 Min reward: -2.25 Mean reward: 1.1597900390625
# update: 4790/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.0397217273712158
# update: 4800/ 9765 Max reward: 77.75 Min reward: -2.25 Mean reward: 0.9595825672149658
# update: 4810/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.0207031965255737
# update: 4820/ 9765 Max reward: 77.5999984741211 Min reward: -2.25 Mean reward: 0.9433594346046448
# update: 4830/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 1.0586183071136475
# update: 4840/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 0.9907105565071106
# update: 4850/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9197266101837158
# update: 4860/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.1721802949905396
# update: 4870/ 9765 Max reward: 78.9000015258789 Min reward: -2.25 Mean reward: 1.2225465774536133
# update: 4880/ 9765 Max reward: 76.05000305175781 Min reward: -2.25 Mean reward: 0.7780762314796448
# update: 4890/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8566651344299316
# update: 4900/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8677735328674316
# update: 4910/ 9765 Max reward: 77.44999694824219 Min reward: -2.25 Mean reward: 1.120324730873108
# update: 4920/ 9765 Max reward: 76.75 Min reward: -2.25 Mean reward: 0.9702271223068237
# update: 4930/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 1.0074830055236816
# update: 4940/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8218995332717896
# update: 4950/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.1598877906799316
# ...
# update: 8130/ 9765 Max reward: 78.9000015258789 Min reward: -2.25 Mean reward: 0.8984375596046448
# update: 8140/ 9765 Max reward: 78.9000015258789 Min reward: -2.25 Mean reward: 1.4107911586761475
# update: 8150/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.3280029296875
# update: 8160/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.25042724609375
# update: 8170/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.0945680141448975
# update: 8180/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.180871605873108
# update: 8190/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.00885009765625
# update: 8200/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9046387672424316
# update: 8210/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.9139405488967896
# update: 8220/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9152222871780396
# update: 8230/ 9765 Max reward: 75.9000015258789 Min reward: -2.25 Mean reward: 1.0377442836761475
# update: 8240/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 1.1468873023986816
# update: 8250/ 9765 Max reward: 78.75 Min reward: -2.25 Mean reward: 0.9382324814796448
# update: 8260/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 1.30633544921875
# update: 8270/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.3532350063323975
# update: 8280/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.3126953840255737
# update: 8290/ 9765 Max reward: 76.75 Min reward: -2.25 Mean reward: 1.2342529296875
# update: 8300/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.2751221656799316
# update: 8310/ 9765 Max reward: 77.75 Min reward: -2.25 Mean reward: 1.3271851539611816
# update: 8320/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.23468017578125
# update: 8330/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.1728272438049316
# update: 8340/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.3902833461761475
# update: 8350/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 1.126708984375
# update: 8360/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 1.0867187976837158
# update: 8370/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 1.0531005859375
# update: 8380/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 1.194421410560608
# update: 8390/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 1.4285402297973633
# update: 8400/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.2830688953399658
# update: 8410/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.2489502429962158
# update: 8420/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.3232421875
# update: 8430/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8552735447883606
# update: 8440/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.3563843965530396
# update: 8450/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.6085084676742554
# update: 8460/ 9765 Max reward: 79.05000305175781 Min reward: -2.25 Mean reward: 1.0917847156524658
# update: 8470/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.11962890625
# update: 8480/ 9765 Max reward: 77.05000305175781 Min reward: -2.25 Mean reward: 1.3073731660842896
# update: 8490/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.3197633028030396
# update: 8500/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.380761742591858
# update: 8510/ 9765 Max reward: 77.5999984741211 Min reward: -2.25 Mean reward: 1.4078125953674316
# update: 8520/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.2079346179962158
# update: 8530/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.0794556140899658
# update: 8540/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.2166870832443237
# update: 8550/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9708740711212158
# update: 8560/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.4314332008361816
# update: 8570/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.2972779273986816
# update: 8580/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.19189453125
# update: 8590/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.2546509504318237
# update: 8600/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.1506104469299316
# update: 8610/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.2078735828399658
# update: 8620/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.3614381551742554
# update: 8630/ 9765 Max reward: 77.75 Min reward: -2.25 Mean reward: 0.9737305641174316
# update: 8640/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 1.1770997047424316
# update: 8650/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.1901733875274658
# update: 8660/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.1138794422149658
# update: 8670/ 9765 Max reward: 77.05000305175781 Min reward: -2.25 Mean reward: 1.0897583961486816
# update: 8680/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.1083862781524658
# update: 8690/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.3287231922149658
# update: 8700/ 9765 Max reward: 76.05000305175781 Min reward: -2.25 Mean reward: 1.3662598133087158
# update: 8710/ 9765 Max reward: 76.75 Min reward: -2.25 Mean reward: 1.3687012195587158
# update: 8720/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9706177711486816
# update: 8730/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.1566895246505737
# update: 8740/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 1.3353271484375
# update: 8750/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.2332642078399658
# update: 8760/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.4526734352111816
# update: 8770/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.1423096656799316
# update: 8780/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.4784058332443237
# update: 8790/ 9765 Max reward: 77.5999984741211 Min reward: -2.25 Mean reward: 1.3556640148162842
# update: 8800/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8817261457443237
# update: 8810/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.1695069074630737
# update: 8820/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.3901491165161133
# update: 8830/ 9765 Max reward: 77.44999694824219 Min reward: -2.25 Mean reward: 1.3480347394943237
# update: 8840/ 9765 Max reward: 76.05000305175781 Min reward: -2.25 Mean reward: 1.1968994140625
# update: 8850/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.7998169660568237
# update: 8860/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.3285279273986816
# update: 8870/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.1490356922149658
# update: 8880/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.251672387123108
# update: 8890/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.4550416469573975
# update: 8900/ 9765 Max reward: 77.75 Min reward: -2.25 Mean reward: 1.2252075672149658
# update: 8910/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.1363037824630737
# update: 8920/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.2328004837036133
# update: 8930/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.2553101778030396
# update: 8940/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.2439086437225342
# update: 8950/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.174743890762329
# update: 8960/ 9765 Max reward: 76.05000305175781 Min reward: -2.25 Mean reward: 1.0341187715530396
# update: 8970/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.3427246809005737
# update: 8980/ 9765 Max reward: 79.05000305175781 Min reward: -2.25 Mean reward: 1.1157349348068237
# update: 8990/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.1058106422424316
# update: 9000/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.183068871498108
# update: 9010/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.3175415992736816
# update: 9020/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.4938600063323975
# update: 9030/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.37017822265625
# update: 9040/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.3410767316818237
# update: 9050/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.3765747547149658
# update: 9060/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.2911744117736816
# update: 9070/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.2451660633087158
# update: 9080/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.0121705532073975
# update: 9090/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.1009767055511475
# update: 9100/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 1.2979615926742554
# update: 9110/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.1044068336486816
# update: 9120/ 9765 Max reward: 77.75 Min reward: -2.25 Mean reward: 1.3690063953399658
# update: 9130/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.1023437976837158
# update: 9140/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 1.3452028036117554
# update: 9150/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.2268555164337158
# update: 9160/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.4628174304962158
# update: 9170/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.2852296829223633
# update: 9180/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 1.4360718727111816
# update: 9190/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.3240234851837158
# update: 9200/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.0564942359924316
# update: 9210/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.1665406227111816
# update: 9220/ 9765 Max reward: 77.44999694824219 Min reward: -2.25 Mean reward: 1.2362061738967896
# update: 9230/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.1390748023986816
# update: 9240/ 9765 Max reward: 78.9000015258789 Min reward: -2.25 Mean reward: 1.0967774391174316
# update: 9250/ 9765 Max reward: 78.75 Min reward: -2.25 Mean reward: 0.9970215559005737
# update: 9260/ 9765 Max reward: 78.9000015258789 Min reward: -2.25 Mean reward: 1.2153198719024658
# update: 9270/ 9765 Max reward: 79.05000305175781 Min reward: -2.25 Mean reward: 1.1069214344024658
# update: 9280/ 9765 Max reward: 77.75 Min reward: -2.25 Mean reward: 1.0834839344024658
# update: 9290/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.3668336868286133
# update: 9300/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.1129883527755737
# update: 9310/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.3405396938323975
# update: 9320/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.2648193836212158
# update: 9330/ 9765 Max reward: 76.05000305175781 Min reward: -2.25 Mean reward: 1.1120117902755737
# update: 9340/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.3898804187774658
# update: 9350/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.3794556856155396
# update: 9360/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 1.1174805164337158
# update: 9370/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.3806397914886475
# update: 9380/ 9765 Max reward: 77.75 Min reward: -2.25 Mean reward: 1.1300415992736816
# update: 9390/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.2318848371505737
# update: 9400/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.3192384243011475
# update: 9410/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.14495849609375
# update: 9420/ 9765 Max reward: 77.75 Min reward: -2.25 Mean reward: 1.1453981399536133
# update: 9430/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.2100830078125
# update: 9440/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.2531616687774658
# update: 9450/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.5309572219848633
# update: 9460/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.0731322765350342
# update: 9470/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 1.5896973609924316
# update: 9480/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.3418457508087158
# update: 9490/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.4199340343475342
# update: 9500/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.1204833984375
# update: 9510/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.0609009265899658
# update: 9520/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.5050660371780396
# update: 9530/ 9765 Max reward: 75.9000015258789 Min reward: -2.25 Mean reward: 1.4250489473342896
# update: 9540/ 9765 Max reward: 76.75 Min reward: -2.25 Mean reward: 1.2286376953125
# update: 9550/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.3890869617462158
# update: 9560/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.1385254859924316
# update: 9570/ 9765 Max reward: 77.5999984741211 Min reward: -2.25 Mean reward: 1.0697999000549316
# update: 9580/ 9765 Max reward: 77.75 Min reward: -2.25 Mean reward: 1.5533204078674316
# update: 9590/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.3948853015899658
# update: 9600/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 1.0782227516174316
# update: 9610/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9928712248802185
# update: 9620/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.3521485328674316
# update: 9630/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.4201661348342896
# update: 9640/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 1.3227906227111816
# update: 9650/ 9765 Max reward: 77.44999694824219 Min reward: -2.25 Mean reward: 1.3366456031799316
# update: 9660/ 9765 Max reward: 78.5999984741211 Min reward: -2.25 Mean reward: 1.3646728992462158
# update: 9670/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.1677613258361816
# update: 9680/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 1.2267091274261475
# update: 9690/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.1288819313049316
# update: 9700/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.2031739950180054
# update: 9710/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.46795654296875
# update: 9720/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.2341797351837158
# update: 9730/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.2257080078125
# update: 9740/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.2508544921875
# update: 9750/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.9162110090255737
# update: 9760/ 9765 Max reward: 76.5999984741211 Min reward: -2.25 Mean reward: 1.0955688953399658

# %%
#Save the model
torch.save(agent.state_dict(), f"models/{run_name}.pt")

# %%
# Load the model
agent = Agent(state_size=state_dim, action_sizes=action_dims, hidden_dim=256)
load_name = 'ScheduleGym-v0__ScheduleTester__1__1723660943'
agent.load_state_dict(torch.load(f"models/{load_name}.pt"))
agent.eval()
agent.to(device)
# Out:
# Agent(
#   (shared): Sequential(
#     (0): Linear(in_features=10, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=256, bias=True)
#     (3): ReLU()
#   )
#   (actor_heads): ModuleList(
#     (0): Linear(in_features=256, out_features=1, bias=True)
#     (1): Linear(in_features=256, out_features=2, bias=True)
#     (2): Linear(in_features=256, out_features=4, bias=True)
#     (3): Linear(in_features=256, out_features=2, bias=True)
#   )
#   (critic): Sequential(
#     (0): Linear(in_features=256, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=1, bias=True)
#   )
# )

# %%
env = ScheduleGym(num_days=2, num_hours=4, num_classes=1, num_subjects=2)

# %%
state, _ = env.reset()

# %%
env.render()
state = torch.Tensor(state).unsqueeze(0).to(device)
action, logprob, _, value = agent.get_action_and_value(state)
state, reward, done, info, _ = env.step(action.squeeze().cpu().numpy())
print(f'Action {action}')
print(f'Reward {reward}')
print(f'Done {done}')

if done:
    print('-'*10)
    print('Episode done')
    env.render()
# Out:
# Class 1:
# Day 1: [1 0 1 0]
# Day 2: [ 0  1 -1 -1]
#
# Fitness: -1.0, Actions left: 37
# Target Hours:
# Class 1: [1 0]
# Action tensor([[1, 0, 1, 2, 0]], device='cuda:0')
# Reward 69.9
# Done True
# ----------
# Episode done
# Class 1:
# Day 1: [1 0 1 0]
# Day 2: [ 0  1  0 -1]
#
# Fitness: 0.0, Actions left: 36
# Target Hours:
# Class 1: [0 0]

# %%
env.render()
# Out:
# Class 1:
# Day 1: [-1 -1 -1  0]
# Day 2: [-1 -1 -1 -1]
#
# Fitness: -1.0, Actions left: 16
# Target Hours:
# Class 1: [0 1]

# %%
action.squeeze().cpu().numpy()
# Out:
# array([0, 0, 3, 0], dtype=int64)

# %%
# Out:
# Action tensor([[0, 0, 3, 0]], device='cuda:0')
# Reward -0.10000000000000009
# Done False

# %%
def visualize_agent(agent, env, n_episodes=5):
    for i_episode in range(1, n_episodes + 1):
        state, info = env.reset()
        done = False
        score = 0
        max_t = 256
        t = 0
        while not done:
            env.render()
            state = torch.FloatTensor(state).unsqueeze(0).to(device)
            #action = agent.choose_action(state)
            action, logprob, _, value = agent.get_action_and_value(state)
            action = action.squeeze().cpu().numpy()
            #action = action.cpu().numpy()
            next_state, reward, done, truncated, info = env.step(action)
            state = next_state
            score += reward
            t += 1
            if done or t >= max_t:
                break
        print(f"Episode {i_episode}\tScore: {score}")
    env.close()

# %%
env = gym.make(args.env_id, render_mode="human")
visualize_agent(agent, env)
# Out:
# Episode 1	Score: -256.0
# Episode 2	Score: -256.0
# Episode 3	Score: -256.0
# Episode 4	Score: -256.0
# Episode 5	Score: -256.0
