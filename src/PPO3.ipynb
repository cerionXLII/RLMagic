# %%
import os
import random
import time
from distutils.util import strtobool

#import gym
from ScheduleGym import ScheduleGym
import gymnasium as gym
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.distributions.categorical import Categorical
from torch.utils.tensorboard import SummaryWriter

from pathlib import Path
import datetime
import tempfile
import json
import shutil
import imageio
from types import SimpleNamespace

# %%
def parse_args():
    # fmt: off
    args = SimpleNamespace()
    args.exp_name = "fiskmacka"
    args.seed = 1
    args.torch_deterministic = True
    args.cuda = True
    args.track = False

    args.capture_video = False
    #args.env_id = "CartPole-v1"
    #args.env_id = "LunarLander-v2"
    args.env_id = "MountainCar-v0"
    args.capture_video = False

    args.total_timesteps = 50000*2*100*4
    args.learning_rate = 2.5e-4
    args.num_envs = 16
    #args.num_steps = 128
    args.num_steps = 256
    args.anneal_lr = True
    args.gae = True
    args.gamma = 0.99
    args.gae_lambda = 0.95
    args.num_minibatches = 4
    args.update_epochs = 4
    args.norm_adv = True

    args.clip_range = 0.2
    args.clip_vloss = True
    args.clip_coef = 0.2
    args.ent_coef = 0.01
    args.vf_coef = 0.5
    args.max_grad_norm = 0.5
    args.target_kl = None
    args.clip_range_vf = None


    args.batch_size = int(args.num_envs * args.num_steps)
    args.minibatch_size = int(args.batch_size // args.num_minibatches)
    # fmt: on
    return args

# %%
args = parse_args()
args
# Out:
# namespace(exp_name='fiskmacka',
#           seed=1,
#           torch_deterministic=True,
#           cuda=True,
#           track=False,
#           capture_video=False,
#           env_id='MountainCar-v0',
#           total_timesteps=40000000,
#           learning_rate=0.00025,
#           num_envs=16,
#           num_steps=256,
#           anneal_lr=True,
#           gae=True,
#           gamma=0.99,
#           gae_lambda=0.95,
#           num_minibatches=4,
#           update_epochs=4,
#           norm_adv=True,
#           clip_range=0.2,
#           clip_vloss=True,
#           clip_coef=0.2,
#           ent_coef=0.01,
#           vf_coef=0.5,
#           max_grad_norm=0.5,
#           target_kl=None,
#           clip_range_vf=None,
#           batch_size=4096,
#           minibatch_size=1024)

# %%
def layer_init(layer, std=np.sqrt(2), bias_const=0.0):
    torch.nn.init.orthogonal_(layer.weight, std)
    torch.nn.init.constant_(layer.bias, bias_const)
    return layer


class Agent(nn.Module):
    def __init__(self, state_size, action_sizes, hidden_dim=256):
        super().__init__()

        self.action_sizes = action_sizes
        self.state_size = state_size

        self.shared = nn.Sequential(
            layer_init(nn.Linear(state_size, hidden_dim)),
            nn.ReLU(),
            layer_init(nn.Linear(hidden_dim, hidden_dim)),
            nn.ReLU()
        )

        self.actor_heads = nn.ModuleList([layer_init(nn.Linear(hidden_dim, dim), std=0.01) for dim in action_sizes])


        self.critic = nn.Sequential(
            layer_init(nn.Linear(hidden_dim, hidden_dim)),
            nn.ReLU(),
            layer_init(nn.Linear(hidden_dim, 1), std=1.0)
        )
        

    def get_value(self, x):
        x = self.shared(x)
        return self.critic(x)

    def get_action_and_value(self, x, action=None):
        # x: (batch_size, state_size)
        x = self.shared(x) # (batch_size, hidden_dim)
        action_logits = [head(x) for head in self.actor_heads] # [(batch_size, action_size) for action_size in action_sizes]
        action_probs = [Categorical(logits=logits) for logits in action_logits] 
        if action is None:
            #action = torch.stack([probs.sample() for probs in action_probs], device=x.device)
            action = torch.stack([probs.sample() for probs in action_probs]).T # (batch_size, len(action_sizes))

        log_prob_sum = torch.stack([probs.log_prob(a) for probs, a in zip(action_probs, action.T)]).sum(dim=0) # (batch_size,)
        entropy_sum = torch.stack([probs.entropy() for probs in action_probs]).sum(dim=0) # (batch_size,)
        return action, log_prob_sum, entropy_sum, self.critic(x)

# %%
args = parse_args()
run_name = f"{args.env_id}__{args.exp_name}__{args.seed}__{int(time.time())}"
random.seed(args.seed)
np.random.seed(args.seed)
torch.manual_seed(args.seed)
torch.backends.cudnn.deterministic = args.torch_deterministic

device = torch.device("cuda" if torch.cuda.is_available() and args.cuda else "cpu")
print(f'Device: {device}')
# Out:
# Device: cuda

# %%
# env setup
# envs = gym.vector.SyncVectorEnv(
#     [make_env(args.env_id, args.seed + i, i, args.capture_video, run_name) for i in range(args.num_envs)]
# )

# %%
# envs = gym.vector.AsyncVectorEnv(
#     [make_env(args.env_id, args.seed + i, i, args.capture_video, run_name) for i in range(args.num_envs)]
# )

# %%
envs = gym.vector.AsyncVectorEnv(
    [lambda: ScheduleGym(num_days=2, num_hours=4, num_classes=1, num_subjects=2) for i in range(args.num_envs)]
)

# %%
state_dim = envs.single_observation_space.shape[0] 
state_dim
# Out:
# 10

# %%
action_dims = [dim.n for dim in envs.single_action_space]
action_dims
# Out:
# [1, 2, 4, 2]

# %%
#override
#device =torch.device('cpu')

# %%
agent = Agent(state_size=state_dim, action_sizes=action_dims, hidden_dim=256).to(device)
optimizer = optim.Adam(agent.parameters(), lr=args.learning_rate, eps=1e-5)

# %%
x, _, = envs.reset()

# %%
x.shape
# Out:
# (16, 10)

# %%
ost = agent.get_value(torch.tensor(x, device=device, dtype=torch.float32))

# %%
ost
# Out:
# tensor([[ 1.0497e-04],
#         [-7.2519e-05],
#         [-1.4062e-03],
#         [-1.0467e-03],
#         [-1.0467e-03],
#         [ 7.4677e-04],
#         [-3.7758e-04],
#         [-1.0467e-03],
#         [-1.9735e-03],
#         [-1.0669e-04],
#         [-1.3313e-05],
#         [-3.7758e-04],
#         [-1.0669e-04],
#         [-3.1334e-04],
#         [-1.9735e-03],
#         [-1.4062e-03]], grad_fn=<AddmmBackward0>)

# %%
action, log_prob_sum, entropy_sum, critic_value= agent.get_action_and_value(torch.tensor(x, device=device, dtype=torch.float32))

# %%
critic_value
# Out:
# tensor([[0.0056],
#         [0.0043],
#         [0.0104],
#         [0.0079],
#         [0.0079],
#         [0.0042],
#         [0.0078],
#         [0.0079],
#         [0.0097],
#         [0.0059],
#         [0.0031],
#         [0.0078],
#         [0.0059],
#         [0.0061],
#         [0.0097],
#         [0.0104]], grad_fn=<AddmmBackward0>)

# %%
(args.num_steps, args.num_envs) + envs.single_observation_space.shape
# Out:
# (256, 16, 10)

# %%
# ALGO Logic: Storage setup
obs = torch.zeros((args.num_steps, args.num_envs) + envs.single_observation_space.shape).to(device)
actions = torch.zeros((args.num_steps, args.num_envs) + envs.single_action_space.shape).to(device)
logprobs = torch.zeros((args.num_steps, args.num_envs)).to(device)
rewards = torch.zeros((args.num_steps, args.num_envs)).to(device)
dones = torch.zeros((args.num_steps, args.num_envs)).to(device)
values = torch.zeros((args.num_steps, args.num_envs)).to(device)

# %%
# TRY NOT TO MODIFY: start the game
global_step = 0
start_time = time.time()
next_obs, _ = envs.reset()
next_obs = torch.Tensor(next_obs).to(device)
next_done = torch.zeros(args.num_envs).to(device)
num_updates = args.total_timesteps // args.batch_size
print(f'Num updates: {num_updates}')
# Out:
# Num updates: 9765

# %%
writer = SummaryWriter(f"runs/{run_name}")
writer.add_text(
    "hyperparameters",
    "|param|value|\n|-|-|\n%s" % ("\n".join([f"|{key}|{value}|" for key, value in vars(args).items()])),
)

# %%
for update in range(1, num_updates + 1):
    # Annealing the rate if instructed to do so.
    if args.anneal_lr:
        frac = 1.0 - (update - 1.0) / num_updates
        lrnow = frac * args.learning_rate
        optimizer.param_groups[0]["lr"] = lrnow

    for step in range(0, args.num_steps):
        global_step += 1 * args.num_envs
        obs[step] = next_obs
        dones[step] = next_done

        # ALGO LOGIC: action logic
        with torch.no_grad():
            action, logprob, _, value = agent.get_action_and_value(next_obs)
            values[step] = value.flatten()
        actions[step] = action
        logprobs[step] = logprob

       
        next_obs, reward, done, info, _ = envs.step(action.cpu().numpy())
        rewards[step] = torch.tensor(reward).to(device).view(-1)
        next_obs, next_done = torch.Tensor(next_obs).to(device), torch.Tensor(done).to(device)

        # for item in info:
        #     if "episode" in item.keys():
        #         print(f"global_step={global_step}, episodic_return={item['episode']['r']}")
        #         writer.add_scalar("charts/episodic_return", item["episode"]["r"], global_step)
        #         writer.add_scalar("charts/episodic_length", item["episode"]["l"], global_step)
        #         break

    # bootstrap value if not done
    with torch.no_grad():
        next_value = agent.get_value(next_obs).reshape(1, -1)
        if args.gae:
            advantages = torch.zeros_like(rewards).to(device)
            lastgaelam = 0
            for t in reversed(range(args.num_steps)):
                if t == args.num_steps - 1:
                    nextnonterminal = 1.0 - next_done
                    nextvalues = next_value
                else:
                    nextnonterminal = 1.0 - dones[t + 1]
                    nextvalues = values[t + 1]
                delta = rewards[t] + args.gamma * nextvalues * nextnonterminal - values[t]
                advantages[t] = lastgaelam = delta + args.gamma * args.gae_lambda * nextnonterminal * lastgaelam
            returns = advantages + values
        else:
            returns = torch.zeros_like(rewards).to(device)
            for t in reversed(range(args.num_steps)):
                if t == args.num_steps - 1:
                    nextnonterminal = 1.0 - next_done
                    next_return = next_value
                else:
                    nextnonterminal = 1.0 - dones[t + 1]
                    next_return = returns[t + 1]
                returns[t] = rewards[t] + args.gamma * nextnonterminal * next_return
            advantages = returns - values

    # flatten the batch
    b_obs = obs.reshape((-1,) + envs.single_observation_space.shape)
    b_logprobs = logprobs.reshape(-1)
    b_actions = actions.reshape((-1,) + envs.single_action_space.shape)
    b_advantages = advantages.reshape(-1)
    b_returns = returns.reshape(-1)
    b_values = values.reshape(-1)

    # Optimizing the policy and value network
    b_inds = np.arange(args.batch_size)
    clipfracs = []
    for epoch in range(args.update_epochs):
        np.random.shuffle(b_inds)
        for start in range(0, args.batch_size, args.minibatch_size):
            end = start + args.minibatch_size
            mb_inds = b_inds[start:end]

            _, newlogprob, entropy, newvalue = agent.get_action_and_value(b_obs[mb_inds], b_actions.long()[mb_inds])
            logratio = newlogprob - b_logprobs[mb_inds]
            ratio = logratio.exp()

            with torch.no_grad():
                # calculate approx_kl http://joschu.net/blog/kl-approx.html
                old_approx_kl = (-logratio).mean()
                approx_kl = ((ratio - 1) - logratio).mean()
                clipfracs += [((ratio - 1.0).abs() > args.clip_coef).float().mean().item()]

            mb_advantages = b_advantages[mb_inds]
            if args.norm_adv:
                mb_advantages = (mb_advantages - mb_advantages.mean()) / (mb_advantages.std() + 1e-8)

            # Policy loss
            pg_loss1 = -mb_advantages * ratio
            pg_loss2 = -mb_advantages * torch.clamp(ratio, 1 - args.clip_coef, 1 + args.clip_coef)
            pg_loss = torch.max(pg_loss1, pg_loss2).mean()

            # Value loss
            newvalue = newvalue.view(-1)
            if args.clip_vloss:
                v_loss_unclipped = (newvalue - b_returns[mb_inds]) ** 2
                v_clipped = b_values[mb_inds] + torch.clamp(
                    newvalue - b_values[mb_inds],
                    -args.clip_coef,
                    args.clip_coef,
                )
                v_loss_clipped = (v_clipped - b_returns[mb_inds]) ** 2
                v_loss_max = torch.max(v_loss_unclipped, v_loss_clipped)
                v_loss = 0.5 * v_loss_max.mean()
            else:
                v_loss = 0.5 * ((newvalue - b_returns[mb_inds]) ** 2).mean()

            entropy_loss = entropy.mean()
            loss = pg_loss - args.ent_coef * entropy_loss + v_loss * args.vf_coef

            optimizer.zero_grad()
            loss.backward()
            nn.utils.clip_grad_norm_(agent.parameters(), args.max_grad_norm)
            optimizer.step()

        if args.target_kl is not None:
            if approx_kl > args.target_kl:
                break

    y_pred, y_true = b_values.cpu().numpy(), b_returns.cpu().numpy()
    var_y = np.var(y_true)
    explained_var = np.nan if var_y == 0 else 1 - np.var(y_true - y_pred) / var_y

    # TRY NOT TO MODIFY: record rewards for plotting purposes
    writer.add_scalar("charts/learning_rate", optimizer.param_groups[0]["lr"], global_step)
    writer.add_scalar("losses/value_loss", v_loss.item(), global_step)
    writer.add_scalar("losses/policy_loss", pg_loss.item(), global_step)
    writer.add_scalar("losses/entropy", entropy_loss.item(), global_step)
    writer.add_scalar("losses/old_approx_kl", old_approx_kl.item(), global_step)
    writer.add_scalar("losses/approx_kl", approx_kl.item(), global_step)
    writer.add_scalar("losses/clipfrac", np.mean(clipfracs), global_step)
    writer.add_scalar("losses/explained_variance", explained_var, global_step)
    writer.add_scalar("charts/SPS", int(global_step / (time.time() - start_time)), global_step)
    writer.add_scalar("mean rewards", rewards.mean().item(), global_step)

    if global_step % 10 == 0:
        print(
            f"update: {update}/ {num_updates} Max reward: {rewards.max().item()} Min reward: {rewards.min().item()} Mean reward: {rewards.mean().item()}"
        )
# Out:
# update: 5/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8064819574356079
# update: 10/ 9765 Max reward: 76.5999984741211 Min reward: -2.25 Mean reward: 0.7869141101837158
# update: 15/ 9765 Max reward: 77.75 Min reward: -2.25 Mean reward: 0.7564942836761475
# update: 20/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 0.6818482279777527
# update: 25/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.00128173828125
# update: 30/ 9765 Max reward: 75.9000015258789 Min reward: -2.25 Mean reward: 0.9180054664611816
# update: 35/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 0.7128907442092896
# update: 40/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8092163801193237
# update: 45/ 9765 Max reward: 77.75 Min reward: -2.25 Mean reward: 0.8044434189796448
# update: 50/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.7391846179962158
# update: 55/ 9765 Max reward: 75.9000015258789 Min reward: -2.25 Mean reward: 0.7060791254043579
# update: 60/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8210816383361816
# update: 65/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9083252549171448
# update: 70/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.5967041850090027
# update: 75/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.7633668184280396
# update: 80/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.9160889387130737
# update: 85/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.7698731422424316
# update: 90/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.7903320789337158
# update: 95/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.7785278558731079
# update: 100/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.7858155965805054
# update: 105/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.7429810762405396
# update: 110/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 0.8397339582443237
# update: 115/ 9765 Max reward: 77.05000305175781 Min reward: -2.25 Mean reward: 1.1926515102386475
# update: 120/ 9765 Max reward: 75.75 Min reward: -2.25 Mean reward: 0.7244507074356079
# update: 125/ 9765 Max reward: 77.5999984741211 Min reward: -2.25 Mean reward: 0.8060913681983948
# update: 130/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9382935762405396
# update: 135/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.7104981541633606
# update: 140/ 9765 Max reward: 78.9000015258789 Min reward: -2.25 Mean reward: 0.8488526344299316
# update: 145/ 9765 Max reward: 75.05000305175781 Min reward: -2.25 Mean reward: 0.7683228254318237
# update: 150/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8924194574356079
# update: 155/ 9765 Max reward: 75.75 Min reward: -2.25 Mean reward: 0.8747315406799316
# update: 160/ 9765 Max reward: 77.75 Min reward: -2.25 Mean reward: 0.8842042088508606
# update: 165/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.5534302592277527
# update: 170/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.7940064072608948
# update: 175/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.6988648176193237
# update: 180/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.7860840559005737
# update: 185/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.6884888410568237
# update: 190/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 0.7490601539611816
# update: 195/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.01446533203125
# update: 200/ 9765 Max reward: 75.75 Min reward: -2.25 Mean reward: 0.8453736305236816
# update: 205/ 9765 Max reward: 77.05000305175781 Min reward: -2.25 Mean reward: 0.8524292707443237
# update: 210/ 9765 Max reward: 77.44999694824219 Min reward: -2.25 Mean reward: 0.6051880717277527
# update: 215/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8647462129592896
# update: 220/ 9765 Max reward: 77.05000305175781 Min reward: -2.25 Mean reward: 0.6313965320587158
# update: 225/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 0.6259888410568237
# update: 230/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 0.7799195051193237
# update: 235/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 0.7389527559280396
# update: 240/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.6376709938049316
# update: 245/ 9765 Max reward: 77.5999984741211 Min reward: -2.25 Mean reward: 0.911877453327179
# update: 250/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8641601800918579
# update: 255/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8064819574356079
# update: 260/ 9765 Max reward: 76.5999984741211 Min reward: -2.25 Mean reward: 0.8466919660568237
# update: 265/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.05865478515625
# update: 270/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.7558472156524658
# update: 275/ 9765 Max reward: 77.5999984741211 Min reward: -2.25 Mean reward: 0.8698853254318237
# update: 280/ 9765 Max reward: 76.75 Min reward: -2.25 Mean reward: 0.8169556260108948
# update: 285/ 9765 Max reward: 78.9000015258789 Min reward: -2.25 Mean reward: 0.8303589224815369
# update: 290/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9391725063323975
# update: 295/ 9765 Max reward: 76.05000305175781 Min reward: -2.25 Mean reward: 0.9078613519668579
# update: 300/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.7200440168380737
# update: 305/ 9765 Max reward: 78.9000015258789 Min reward: -2.25 Mean reward: 0.7174805402755737
# update: 310/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.0022584199905396
# update: 315/ 9765 Max reward: 77.75 Min reward: -2.25 Mean reward: 0.8074096441268921
# update: 320/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8352051973342896
# update: 325/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8978272080421448
# update: 330/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 0.6356568336486816
# update: 335/ 9765 Max reward: 77.5999984741211 Min reward: -2.25 Mean reward: 0.8468628525733948
# update: 340/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.7287964820861816
# update: 345/ 9765 Max reward: 75.9000015258789 Min reward: -2.25 Mean reward: 0.7762573957443237
# update: 350/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8252441883087158
# update: 355/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.9267090559005737
# update: 360/ 9765 Max reward: 78.75 Min reward: -2.25 Mean reward: 0.6935303211212158
# update: 365/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.0088379383087158
# update: 370/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.8386597633361816
# update: 375/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8038697242736816
# update: 380/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8839234113693237
# update: 385/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.7416260242462158
# update: 390/ 9765 Max reward: 76.75 Min reward: -2.25 Mean reward: 0.6636841297149658
# update: 395/ 9765 Max reward: 77.05000305175781 Min reward: -2.25 Mean reward: 0.8973145484924316
# update: 400/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.8529785871505737
# update: 405/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8295776844024658
# update: 410/ 9765 Max reward: 77.44999694824219 Min reward: -2.25 Mean reward: 0.6889282464981079
# update: 415/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.7537354230880737
# update: 420/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9940063953399658
# update: 425/ 9765 Max reward: 77.44999694824219 Min reward: -2.25 Mean reward: 0.8554444313049316
# update: 430/ 9765 Max reward: 76.5999984741211 Min reward: -2.25 Mean reward: 0.9918336272239685
# update: 435/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 0.9615356922149658
# update: 440/ 9765 Max reward: 75.5999984741211 Min reward: -2.25 Mean reward: 1.1146728992462158
# update: 445/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.9476685523986816
# update: 450/ 9765 Max reward: 77.5999984741211 Min reward: -2.25 Mean reward: 1.0104737281799316
# update: 455/ 9765 Max reward: 77.5999984741211 Min reward: -2.25 Mean reward: 0.7458740472793579
# update: 460/ 9765 Max reward: 76.5999984741211 Min reward: -2.25 Mean reward: 0.7588501572608948
# update: 465/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8469482660293579
# update: 470/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 0.7874634265899658
# update: 475/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.7364380955696106
# update: 480/ 9765 Max reward: 78.9000015258789 Min reward: -2.25 Mean reward: 0.954113781452179
# update: 485/ 9765 Max reward: 77.75 Min reward: -2.25 Mean reward: 1.0330078601837158
# update: 490/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 0.7043336033821106
# update: 495/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9619386196136475
# update: 500/ 9765 Max reward: 76.75 Min reward: -2.25 Mean reward: 0.7858520746231079
# update: 505/ 9765 Max reward: 77.75 Min reward: -2.25 Mean reward: 0.9428834319114685
# update: 510/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 0.6277344226837158
# update: 515/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.7248047590255737
# update: 520/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8763917088508606
# update: 525/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.9294923543930054
# update: 530/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8670166730880737
# update: 535/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.0295898914337158
# update: 540/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.7848755717277527
# update: 545/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.7201905250549316
# update: 550/ 9765 Max reward: 75.5999984741211 Min reward: -2.25 Mean reward: 0.6997437477111816
# update: 555/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.0794068574905396
# update: 560/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.018701195716858
# update: 565/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.9485108852386475
# update: 570/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.8788574934005737
# update: 575/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 0.9883424043655396
# update: 580/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.5783326625823975
# update: 585/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.9555909633636475
# update: 590/ 9765 Max reward: 75.9000015258789 Min reward: -2.25 Mean reward: 1.0603638887405396
# update: 595/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.962597668170929
# update: 600/ 9765 Max reward: 77.05000305175781 Min reward: -2.25 Mean reward: 0.6548218727111816
# update: 605/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.9121827483177185
# update: 610/ 9765 Max reward: 75.5999984741211 Min reward: -2.25 Mean reward: 0.9859254360198975
# update: 615/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.7952394485473633
# update: 620/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8739625215530396
# update: 625/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.7336548566818237
# update: 630/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.8026367425918579
# update: 635/ 9765 Max reward: 76.44999694824219 Min reward: -2.25 Mean reward: 0.7213257551193237
# update: 640/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 0.8672119975090027
# update: 645/ 9765 Max reward: 78.9000015258789 Min reward: -2.25 Mean reward: 0.7138184905052185
# update: 650/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.0067138671875
# update: 655/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.9188110828399658
# update: 660/ 9765 Max reward: 79.05000305175781 Min reward: -2.25 Mean reward: 0.8251831531524658
# update: 665/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 0.7075928449630737
# update: 670/ 9765 Max reward: 77.44999694824219 Min reward: -2.25 Mean reward: 0.8478760719299316
# update: 675/ 9765 Max reward: 75.9000015258789 Min reward: -2.25 Mean reward: 0.6648805141448975
# update: 680/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.6481690406799316
# update: 685/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.9334107637405396
# update: 690/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.9580689668655396
# update: 695/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 0.8079102635383606
# update: 700/ 9765 Max reward: 77.05000305175781 Min reward: -2.25 Mean reward: 0.8075928688049316
# update: 705/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8976929187774658
# update: 710/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8608033061027527
# update: 715/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.7604615092277527
# update: 720/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.0465455055236816
# update: 725/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8480225801467896
# update: 730/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.7861206531524658
# update: 735/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8485596776008606
# update: 740/ 9765 Max reward: 78.9000015258789 Min reward: -2.25 Mean reward: 0.7824952006340027
# update: 745/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9654420018196106
# update: 750/ 9765 Max reward: 77.44999694824219 Min reward: -2.25 Mean reward: 0.8312744498252869
# update: 755/ 9765 Max reward: 77.44999694824219 Min reward: -2.25 Mean reward: 0.7611451148986816
# update: 760/ 9765 Max reward: 74.9000015258789 Min reward: -2.25 Mean reward: 1.1246337890625
# update: 765/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9941895008087158
# update: 770/ 9765 Max reward: 75.44999694824219 Min reward: -2.25 Mean reward: 0.8357545137405396
# update: 775/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.7802125215530396
# update: 780/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 0.7597168684005737
# update: 785/ 9765 Max reward: 79.05000305175781 Min reward: -2.25 Mean reward: 0.7900269031524658
# update: 790/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.9330567121505737
# update: 795/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8953858613967896
# update: 800/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9476563334465027
# update: 805/ 9765 Max reward: 77.5999984741211 Min reward: -2.25 Mean reward: 0.7172729969024658
# update: 810/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8641968369483948
# update: 815/ 9765 Max reward: 77.05000305175781 Min reward: -2.25 Mean reward: 0.8502930402755737
# update: 820/ 9765 Max reward: 75.75 Min reward: -2.25 Mean reward: 0.9399170875549316
# update: 825/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8155884742736816
# update: 830/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.7317383289337158
# update: 835/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.7822266221046448
# update: 840/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 0.7632569074630737
# update: 845/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 0.9054810404777527
# update: 850/ 9765 Max reward: 75.5999984741211 Min reward: -2.25 Mean reward: 0.8757812976837158
# update: 855/ 9765 Max reward: 77.44999694824219 Min reward: -2.25 Mean reward: 0.8461426496505737
# update: 860/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.7968873381614685
# update: 865/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.6704102158546448
# update: 870/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.7429810762405396
# update: 875/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 0.9044922590255737
# update: 880/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9170288443565369
# update: 885/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.7571533918380737
# update: 890/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 0.6695557236671448
# update: 895/ 9765 Max reward: 74.75 Min reward: -2.25 Mean reward: 1.0089356899261475
# update: 900/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.6876465082168579
# update: 905/ 9765 Max reward: 78.9000015258789 Min reward: -2.25 Mean reward: 0.8956787586212158
# update: 910/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.6321778297424316
# update: 915/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.0869873762130737
# update: 920/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8787109851837158
# update: 925/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.1680908203125
# update: 930/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.6405029892921448
# update: 935/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 0.6656861305236816
# update: 940/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.7162476181983948
# update: 945/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.7443726062774658
# update: 950/ 9765 Max reward: 76.75 Min reward: -2.25 Mean reward: 0.6247559189796448
# update: 955/ 9765 Max reward: 76.44999694824219 Min reward: -2.25 Mean reward: 0.7450440526008606
# update: 960/ 9765 Max reward: 78.9000015258789 Min reward: -2.25 Mean reward: 0.8537110090255737
# update: 965/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 0.8178101181983948
# update: 970/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.9053345322608948
# update: 975/ 9765 Max reward: 78.9000015258789 Min reward: -2.25 Mean reward: 0.8955689668655396
# update: 980/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8125122785568237
# update: 985/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8583496809005737
# update: 990/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.9034180045127869
# update: 995/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.9679077863693237
# update: 1000/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8324707746505737
# update: 1005/ 9765 Max reward: 77.5999984741211 Min reward: -2.25 Mean reward: 1.1015381813049316
# update: 1010/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8457886576652527
# update: 1015/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9885621070861816
# update: 1020/ 9765 Max reward: 77.5999984741211 Min reward: -2.25 Mean reward: 0.7614747285842896
# update: 1025/ 9765 Max reward: 78.9000015258789 Min reward: -2.25 Mean reward: 0.8584595918655396
# update: 1030/ 9765 Max reward: 77.75 Min reward: -2.25 Mean reward: 0.8882446885108948
# update: 1035/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.1344727277755737
# update: 1040/ 9765 Max reward: 75.75 Min reward: -2.25 Mean reward: 0.9374145865440369
# update: 1045/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8171876072883606
# update: 1050/ 9765 Max reward: 76.75 Min reward: -2.25 Mean reward: 0.9217041730880737
# update: 1055/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 0.8677612543106079
# update: 1060/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 0.8525513410568237
# update: 1065/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8979980945587158
# update: 1070/ 9765 Max reward: 77.5999984741211 Min reward: -2.25 Mean reward: 0.9266968965530396
# update: 1075/ 9765 Max reward: 74.9000015258789 Min reward: -2.25 Mean reward: 0.9389405250549316
# update: 1080/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.7206422090530396
# update: 1085/ 9765 Max reward: 76.5999984741211 Min reward: -2.25 Mean reward: 1.2249268293380737
# update: 1090/ 9765 Max reward: 79.05000305175781 Min reward: -2.25 Mean reward: 0.6669678688049316
# update: 1095/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.9357300400733948
# update: 1100/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.1101441383361816
# update: 1105/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.7944214344024658
# update: 1110/ 9765 Max reward: 76.05000305175781 Min reward: -2.25 Mean reward: 0.8194581270217896
# update: 1115/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8778809905052185
# update: 1120/ 9765 Max reward: 78.75 Min reward: -2.25 Mean reward: 0.8589722514152527
# update: 1125/ 9765 Max reward: 78.75 Min reward: -2.25 Mean reward: 0.8000000715255737
# update: 1130/ 9765 Max reward: 77.5999984741211 Min reward: -2.25 Mean reward: 1.0039918422698975
# update: 1135/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.7904785871505737
# update: 1140/ 9765 Max reward: 78.9000015258789 Min reward: -2.25 Mean reward: 0.8354981541633606
# update: 1145/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.0687257051467896
# update: 1150/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 0.8507813215255737
# update: 1155/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8266724348068237
# update: 1160/ 9765 Max reward: 75.75 Min reward: -2.25 Mean reward: 0.9044678211212158
# update: 1165/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9127442240715027
# update: 1170/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.7589600086212158
# update: 1175/ 9765 Max reward: 75.9000015258789 Min reward: -2.25 Mean reward: 0.8824585676193237
# update: 1180/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 0.8765991926193237
# update: 1185/ 9765 Max reward: 76.05000305175781 Min reward: -2.25 Mean reward: 0.8890259265899658
# update: 1190/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.0081177949905396
# update: 1195/ 9765 Max reward: 77.05000305175781 Min reward: -2.25 Mean reward: 0.6763672828674316
# update: 1200/ 9765 Max reward: 77.44999694824219 Min reward: -2.25 Mean reward: 0.9590699076652527
# update: 1205/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8282593488693237
# update: 1210/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.7876465320587158
# update: 1215/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.7220215201377869
# update: 1220/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.8192627429962158
# update: 1225/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.0180175304412842
# update: 1230/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.842236340045929
# update: 1235/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.0794191360473633
# update: 1240/ 9765 Max reward: 78.9000015258789 Min reward: -2.25 Mean reward: 0.8713746070861816
# update: 1245/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8431642055511475
# update: 1250/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.9340820908546448
# update: 1255/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 1.040795922279358
# update: 1260/ 9765 Max reward: 78.75 Min reward: -2.25 Mean reward: 0.7765381336212158
# update: 1265/ 9765 Max reward: 77.75 Min reward: -2.25 Mean reward: 0.7353639006614685
# update: 1270/ 9765 Max reward: 76.5999984741211 Min reward: -2.25 Mean reward: 1.1072754859924316
# update: 1275/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 1.0597290992736816
# update: 1280/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.0712647438049316
# update: 1285/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9503419399261475
# update: 1290/ 9765 Max reward: 75.44999694824219 Min reward: -2.25 Mean reward: 0.8961548805236816
# update: 1295/ 9765 Max reward: 77.5999984741211 Min reward: -2.25 Mean reward: 1.0535645484924316
# update: 1300/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.7229615449905396
# update: 1305/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9637818336486816
# update: 1310/ 9765 Max reward: 78.9000015258789 Min reward: -2.25 Mean reward: 0.9869384765625
# update: 1315/ 9765 Max reward: 78.75 Min reward: -2.25 Mean reward: 0.7808839082717896
# update: 1320/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.9987305998802185
# update: 1325/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.7361328601837158
# update: 1330/ 9765 Max reward: 76.75 Min reward: -2.25 Mean reward: 0.9747803211212158
# update: 1335/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8474243879318237
# update: 1340/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.7880982160568237
# update: 1345/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.1052857637405396
# update: 1350/ 9765 Max reward: 75.9000015258789 Min reward: -2.25 Mean reward: 1.0543214082717896
# update: 1355/ 9765 Max reward: 76.05000305175781 Min reward: -2.25 Mean reward: 0.9138794541358948
# update: 1360/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.030236840248108
# update: 1365/ 9765 Max reward: 78.75 Min reward: -2.25 Mean reward: 0.9564819931983948
# update: 1370/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 0.6336670517921448
# update: 1375/ 9765 Max reward: 75.9000015258789 Min reward: -2.25 Mean reward: 0.6943970918655396
# update: 1380/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 0.7913696765899658
# update: 1385/ 9765 Max reward: 75.9000015258789 Min reward: -2.25 Mean reward: 0.8731567859649658
# update: 1390/ 9765 Max reward: 78.9000015258789 Min reward: -2.25 Mean reward: 0.9181762933731079
# update: 1395/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.6296142935752869
# update: 1400/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 1.0014526844024658
# update: 1405/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.7873291969299316
# update: 1410/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8787475824356079
# update: 1415/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.7449342012405396
# update: 1420/ 9765 Max reward: 76.5999984741211 Min reward: -2.25 Mean reward: 0.8512085676193237
# update: 1425/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9483887553215027
# update: 1430/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8708984851837158
# update: 1435/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.0592163801193237
# update: 1440/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 0.9984863996505737
# update: 1445/ 9765 Max reward: 76.75 Min reward: -2.25 Mean reward: 0.8897339701652527
# update: 1450/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.0753419399261475
# update: 1455/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8928955793380737
# update: 1460/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.6462159156799316
# update: 1465/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.9542847275733948
# update: 1470/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.7137207984924316
# update: 1475/ 9765 Max reward: 78.5999984741211 Min reward: -2.25 Mean reward: 0.7181642055511475
# update: 1480/ 9765 Max reward: 77.5999984741211 Min reward: -2.25 Mean reward: 0.7031372785568237
# update: 1485/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.7490723133087158
# update: 1490/ 9765 Max reward: 77.5999984741211 Min reward: -2.25 Mean reward: 1.0145386457443237
# update: 1495/ 9765 Max reward: 77.75 Min reward: -2.25 Mean reward: 0.7893310785293579
# update: 1500/ 9765 Max reward: 75.9000015258789 Min reward: -2.25 Mean reward: 0.9976685643196106
# update: 1505/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8636597394943237
# update: 1510/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.7140991687774658
# update: 1515/ 9765 Max reward: 77.5999984741211 Min reward: -2.25 Mean reward: 0.7954590320587158
# update: 1520/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9126709699630737
# update: 1525/ 9765 Max reward: 77.5999984741211 Min reward: -2.25 Mean reward: 0.8499512672424316
# update: 1530/ 9765 Max reward: 78.5999984741211 Min reward: -2.25 Mean reward: 0.9639527201652527
# update: 1535/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 0.8507813215255737
# update: 1540/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8098145127296448
# update: 1545/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8231201767921448
# update: 1550/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.0287599563598633
# update: 1555/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.9433472156524658
# update: 1560/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9761109352111816
# update: 1565/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 1.0199341773986816
# update: 1570/ 9765 Max reward: 76.5999984741211 Min reward: -2.25 Mean reward: 0.9549683332443237
# update: 1575/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.7640625238418579
# update: 1580/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.0586183071136475
# update: 1585/ 9765 Max reward: 77.75 Min reward: -2.25 Mean reward: 0.8921387195587158
# update: 1590/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8368897438049316
# update: 1595/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9556519389152527
# update: 1600/ 9765 Max reward: 78.9000015258789 Min reward: -2.25 Mean reward: 0.9505005478858948
# update: 1605/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 1.0439941883087158
# update: 1610/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.9583985209465027
# update: 1615/ 9765 Max reward: 78.9000015258789 Min reward: -2.25 Mean reward: 0.9404541254043579
# update: 1620/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.8580933809280396
# update: 1625/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.6514405012130737
# update: 1630/ 9765 Max reward: 76.75 Min reward: -2.25 Mean reward: 0.8379883170127869
# update: 1635/ 9765 Max reward: 77.5999984741211 Min reward: -2.25 Mean reward: 0.78912353515625
# update: 1640/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8285889029502869
# update: 1645/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8807251453399658
# update: 1650/ 9765 Max reward: 77.75 Min reward: -2.25 Mean reward: 0.8038941025733948
# update: 1655/ 9765 Max reward: 78.5999984741211 Min reward: -2.25 Mean reward: 0.6507691144943237
# update: 1660/ 9765 Max reward: 77.05000305175781 Min reward: -2.25 Mean reward: 1.0820435285568237
# update: 1665/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.6283447742462158
# update: 1670/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8238526582717896
# update: 1675/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.8502197861671448
# update: 1680/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.7920532822608948
# update: 1685/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8340943455696106
# update: 1690/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.8276978135108948
# update: 1695/ 9765 Max reward: 78.9000015258789 Min reward: -2.25 Mean reward: 0.8237916231155396
# update: 1700/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8761230707168579
# update: 1705/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 0.8191773891448975
# update: 1710/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.8160523176193237
# update: 1715/ 9765 Max reward: 77.5999984741211 Min reward: -2.25 Mean reward: 1.0042725801467896
# update: 1720/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.6935547590255737
# update: 1725/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 1.0433350801467896
# update: 1730/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.0153931379318237
# update: 1735/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8407959938049316
# update: 1740/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.6801514625549316
# update: 1745/ 9765 Max reward: 78.5999984741211 Min reward: -2.25 Mean reward: 0.7554444074630737
# update: 1750/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9262452125549316
# update: 1755/ 9765 Max reward: 77.05000305175781 Min reward: -2.25 Mean reward: 0.7559082508087158
# update: 1760/ 9765 Max reward: 75.9000015258789 Min reward: -2.25 Mean reward: 0.7920533418655396
# update: 1765/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8562622666358948
# update: 1770/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9129517078399658
# update: 1775/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 0.9655396938323975
# update: 1780/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.7155762910842896
# update: 1785/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9333496689796448
# update: 1790/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.8301270604133606
# update: 1795/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.7303833365440369
# update: 1800/ 9765 Max reward: 77.5999984741211 Min reward: -2.25 Mean reward: 0.9238160252571106
# update: 1805/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8047852516174316
# update: 1810/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8940064311027527
# update: 1815/ 9765 Max reward: 77.75 Min reward: -2.25 Mean reward: 0.7896118760108948
# update: 1820/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 0.7691285014152527
# update: 1825/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8470947742462158
# update: 1830/ 9765 Max reward: 75.9000015258789 Min reward: -2.25 Mean reward: 0.7901123762130737
# update: 1835/ 9765 Max reward: 78.9000015258789 Min reward: -2.25 Mean reward: 1.0429688692092896
# update: 1840/ 9765 Max reward: 79.05000305175781 Min reward: -2.25 Mean reward: 0.7164551615715027
# update: 1845/ 9765 Max reward: 75.75 Min reward: -2.25 Mean reward: 0.9969483017921448
# update: 1850/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.1094238758087158
# update: 1855/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.2693727016448975
# update: 1860/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 1.0862183570861816
# update: 1865/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8833252191543579
# update: 1870/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8526489734649658
# update: 1875/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.7529664039611816
# update: 1880/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.9311646223068237
# update: 1885/ 9765 Max reward: 76.5999984741211 Min reward: -2.25 Mean reward: 0.8600342273712158
# update: 1890/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.8918213844299316
# update: 1895/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.9177735447883606
# update: 1900/ 9765 Max reward: 77.05000305175781 Min reward: -2.25 Mean reward: 0.7221313714981079
# update: 1905/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.7073487043380737
# update: 1910/ 9765 Max reward: 75.5999984741211 Min reward: -2.25 Mean reward: 0.6953126192092896
# update: 1915/ 9765 Max reward: 79.05000305175781 Min reward: -2.25 Mean reward: 0.7783203721046448
# update: 1920/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9354981184005737
# update: 1925/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.9620240330696106
# update: 1930/ 9765 Max reward: 77.75 Min reward: -2.25 Mean reward: 0.7776978015899658
# update: 1935/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.7613892555236816
# update: 1940/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 1.1315064430236816
# update: 1945/ 9765 Max reward: 75.9000015258789 Min reward: -2.25 Mean reward: 0.7489502429962158
# update: 1950/ 9765 Max reward: 77.5999984741211 Min reward: -2.25 Mean reward: 0.8629029393196106
# update: 1955/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.8424927592277527
# update: 1960/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 0.9081056118011475
# update: 1965/ 9765 Max reward: 75.75 Min reward: -2.25 Mean reward: 1.0087281465530396
# update: 1970/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 1.1113404035568237
# update: 1975/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.870617687702179
# update: 1980/ 9765 Max reward: 77.75 Min reward: -2.25 Mean reward: 0.8642700910568237
# update: 1985/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 0.6828979849815369
# update: 1990/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 0.7300416231155396
# update: 1995/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8357666730880737
# update: 2000/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8433350324630737
# update: 2005/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.7339966297149658
# update: 2010/ 9765 Max reward: 78.9000015258789 Min reward: -2.25 Mean reward: 1.0032715797424316
# update: 2015/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.9101318717002869
# update: 2020/ 9765 Max reward: 78.75 Min reward: -2.25 Mean reward: 0.8222656846046448
# update: 2025/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9319946765899658
# update: 2030/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8177124261856079
# update: 2035/ 9765 Max reward: 76.5999984741211 Min reward: -2.25 Mean reward: 0.7401734590530396
# update: 2040/ 9765 Max reward: 77.75 Min reward: -2.25 Mean reward: 0.8782349228858948
# update: 2045/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 0.8569824695587158
# update: 2050/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.9235352277755737
# update: 2055/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9505738019943237
# update: 2060/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 0.8043701648712158
# update: 2065/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.7951294183731079
# update: 2070/ 9765 Max reward: 76.75 Min reward: -2.25 Mean reward: 1.1119751930236816
# update: 2075/ 9765 Max reward: 77.5999984741211 Min reward: -2.25 Mean reward: 0.8185181617736816
# update: 2080/ 9765 Max reward: 75.44999694824219 Min reward: -2.25 Mean reward: 0.81494140625
# update: 2085/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.0354737043380737
# update: 2090/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 0.8906250596046448
# update: 2095/ 9765 Max reward: 75.75 Min reward: -2.25 Mean reward: 0.8233399391174316
# update: 2100/ 9765 Max reward: 77.05000305175781 Min reward: -2.25 Mean reward: 0.7037354707717896
# update: 2105/ 9765 Max reward: 77.05000305175781 Min reward: -2.25 Mean reward: 0.853649914264679
# update: 2110/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.842419445514679
# update: 2115/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.7099243402481079
# update: 2120/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8024170398712158
# update: 2125/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.9311401844024658
# update: 2130/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.9419434666633606
# update: 2135/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9778443574905396
# update: 2140/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 0.9427247047424316
# update: 2145/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 0.7461060285568237
# update: 2150/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 0.7396728992462158
# update: 2155/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 0.9901123046875
# update: 2160/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.7954102754592896
# update: 2165/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8263672590255737
# update: 2170/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9266968965530396
# update: 2175/ 9765 Max reward: 76.75 Min reward: -2.25 Mean reward: 0.7571533918380737
# update: 2180/ 9765 Max reward: 77.75 Min reward: -2.25 Mean reward: 1.0894410610198975
# update: 2185/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8531250357627869
# update: 2190/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9727051258087158
# update: 2195/ 9765 Max reward: 77.5999984741211 Min reward: -2.25 Mean reward: 0.9701050519943237
# update: 2200/ 9765 Max reward: 77.05000305175781 Min reward: -2.25 Mean reward: 0.8645752668380737
# update: 2205/ 9765 Max reward: 77.75 Min reward: -2.25 Mean reward: 0.8750000596046448
# update: 2210/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8163086771965027
# update: 2215/ 9765 Max reward: 78.5999984741211 Min reward: -2.25 Mean reward: 0.7791993021965027
# update: 2220/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.0048584938049316
# update: 2225/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.0759644508361816
# update: 2230/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8439698219299316
# update: 2235/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.9720337986946106
# update: 2240/ 9765 Max reward: 77.75 Min reward: -2.25 Mean reward: 0.7201783061027527
# update: 2245/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8244751691818237
# update: 2250/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9653198719024658
# update: 2255/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8554199934005737
# update: 2260/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.748095691204071
# update: 2265/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.0247070789337158
# update: 2270/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.7812012434005737
# update: 2275/ 9765 Max reward: 76.44999694824219 Min reward: -2.25 Mean reward: 0.9607300758361816
# update: 2280/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 0.6660279035568237
# update: 2285/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8993287086486816
# update: 2290/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 0.8487793803215027
# update: 2295/ 9765 Max reward: 75.9000015258789 Min reward: -2.25 Mean reward: 0.8134522438049316
# update: 2300/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.9150391817092896
# update: 2305/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.0232789516448975
# update: 2310/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.7986694574356079
# update: 2315/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 0.7989136576652527
# update: 2320/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8253906965255737
# update: 2325/ 9765 Max reward: 77.75 Min reward: -2.25 Mean reward: 1.0203980207443237
# update: 2330/ 9765 Max reward: 75.75 Min reward: -2.25 Mean reward: 0.9702638387680054
# update: 2335/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.9338501691818237
# update: 2340/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.1496094465255737
# update: 2345/ 9765 Max reward: 76.5999984741211 Min reward: -2.25 Mean reward: 0.7622681260108948
# update: 2350/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8802002668380737
# update: 2355/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.7886841297149658
# update: 2360/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.0568604469299316
# update: 2365/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 0.8549195528030396
# update: 2370/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.7314820289611816
# update: 2375/ 9765 Max reward: 78.9000015258789 Min reward: -2.25 Mean reward: 0.6682862043380737
# update: 2380/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8326417207717896
# update: 2385/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.6326538920402527
# update: 2390/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.9291504621505737
# update: 2395/ 9765 Max reward: 78.9000015258789 Min reward: -2.25 Mean reward: 0.6210816502571106
# update: 2400/ 9765 Max reward: 78.9000015258789 Min reward: -2.25 Mean reward: 0.7706421613693237
# update: 2405/ 9765 Max reward: 76.75 Min reward: -2.25 Mean reward: 1.0152589082717896
# update: 2410/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 0.7871949076652527
# update: 2415/ 9765 Max reward: 76.75 Min reward: -2.25 Mean reward: 0.9972656965255737
# update: 2420/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 0.9459840059280396
# update: 2425/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 0.8168457746505737
# update: 2430/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 0.8075928688049316
# update: 2435/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8479492664337158
# update: 2440/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.1171387434005737
# update: 2445/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.9964233636856079
# update: 2450/ 9765 Max reward: 76.44999694824219 Min reward: -2.25 Mean reward: 0.9521118402481079
# update: 2455/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9850342273712158
# update: 2460/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8609620332717896
# update: 2465/ 9765 Max reward: 75.9000015258789 Min reward: -2.25 Mean reward: 0.9071534276008606
# update: 2470/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.9593873023986816
# update: 2475/ 9765 Max reward: 76.05000305175781 Min reward: -2.25 Mean reward: 0.8330933451652527
# update: 2480/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 1.06842041015625
# ...
# update: 8950/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 1.3869507312774658
# update: 8955/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.3563477993011475
# update: 8960/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.2695679664611816
# update: 8965/ 9765 Max reward: 78.75 Min reward: -2.25 Mean reward: 0.9780884385108948
# update: 8970/ 9765 Max reward: 77.44999694824219 Min reward: -2.25 Mean reward: 1.3459839820861816
# update: 8975/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.1620240211486816
# update: 8980/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.335107445716858
# update: 8985/ 9765 Max reward: 78.9000015258789 Min reward: -2.25 Mean reward: 1.0214600563049316
# update: 8990/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.4235230684280396
# update: 8995/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 1.2283447980880737
# update: 9000/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 0.8593140840530396
# update: 9005/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.0136353969573975
# update: 9010/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8596192002296448
# update: 9015/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.256982445716858
# update: 9020/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8448364734649658
# update: 9025/ 9765 Max reward: 78.9000015258789 Min reward: -2.25 Mean reward: 1.2366700172424316
# update: 9030/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.3046021461486816
# update: 9035/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.1274292469024658
# update: 9040/ 9765 Max reward: 77.75 Min reward: -2.25 Mean reward: 1.0027954578399658
# update: 9045/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.0755860805511475
# update: 9050/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.2362793684005737
# update: 9055/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8805909156799316
# update: 9060/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.3326904773712158
# update: 9065/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.0556275844573975
# update: 9070/ 9765 Max reward: 78.9000015258789 Min reward: -2.25 Mean reward: 1.078271508216858
# update: 9075/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 1.0202271938323975
# update: 9080/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9456299543380737
# update: 9085/ 9765 Max reward: 76.75 Min reward: -2.25 Mean reward: 1.1556519269943237
# update: 9090/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.0542969703674316
# update: 9095/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.1015260219573975
# update: 9100/ 9765 Max reward: 78.9000015258789 Min reward: -2.25 Mean reward: 1.0164430141448975
# update: 9105/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.0037477016448975
# update: 9110/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 1.2798707485198975
# update: 9115/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9937744736671448
# update: 9120/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.1203858852386475
# update: 9125/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.1578370332717896
# update: 9130/ 9765 Max reward: 77.5999984741211 Min reward: -2.25 Mean reward: 1.0734374523162842
# update: 9135/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 0.9442261457443237
# update: 9140/ 9765 Max reward: 76.75 Min reward: -2.25 Mean reward: 1.1892457008361816
# update: 9145/ 9765 Max reward: 78.5999984741211 Min reward: -2.25 Mean reward: 1.4311280250549316
# update: 9150/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.202880859375
# update: 9155/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.1961305141448975
# update: 9160/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 1.0418213605880737
# update: 9165/ 9765 Max reward: 77.75 Min reward: -2.25 Mean reward: 1.3073976039886475
# update: 9170/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.0895020961761475
# update: 9175/ 9765 Max reward: 77.75 Min reward: -2.25 Mean reward: 0.9338867664337158
# update: 9180/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.1230591535568237
# update: 9185/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.053857445716858
# update: 9190/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.9723390340805054
# update: 9195/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.8865967392921448
# update: 9200/ 9765 Max reward: 75.75 Min reward: -2.25 Mean reward: 1.0446168184280396
# update: 9205/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 1.0683350563049316
# update: 9210/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.0747926235198975
# update: 9215/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 1.343017578125
# update: 9220/ 9765 Max reward: 76.5999984741211 Min reward: -2.25 Mean reward: 1.1333009004592896
# update: 9225/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 1.4202759265899658
# update: 9230/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.952893078327179
# update: 9235/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.1046631336212158
# update: 9240/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9643310904502869
# update: 9245/ 9765 Max reward: 76.05000305175781 Min reward: -2.25 Mean reward: 0.9930542707443237
# update: 9250/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.1012208461761475
# update: 9255/ 9765 Max reward: 77.75 Min reward: -2.25 Mean reward: 0.9042969942092896
# update: 9260/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.0633057355880737
# update: 9265/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 1.1348512172698975
# update: 9270/ 9765 Max reward: 77.05000305175781 Min reward: -2.25 Mean reward: 1.1705200672149658
# update: 9275/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9647095203399658
# update: 9280/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.1120728254318237
# update: 9285/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.0885987281799316
# update: 9290/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 1.2902344465255737
# update: 9295/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 1.2822754383087158
# update: 9300/ 9765 Max reward: 77.44999694824219 Min reward: -2.25 Mean reward: 1.2179322242736816
# update: 9305/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.1357910633087158
# update: 9310/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.0456299781799316
# update: 9315/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.084558129310608
# update: 9320/ 9765 Max reward: 76.75 Min reward: -2.25 Mean reward: 1.194238305091858
# update: 9325/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 1.2060546875
# update: 9330/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.1283692121505737
# update: 9335/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.3840577602386475
# update: 9340/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.1338746547698975
# update: 9345/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.3136720657348633
# update: 9350/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9106079936027527
# update: 9355/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.1427613496780396
# update: 9360/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.0296998023986816
# update: 9365/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 0.8990601301193237
# update: 9370/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.9939332008361816
# update: 9375/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.1728761196136475
# update: 9380/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.07110595703125
# update: 9385/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 1.1344361305236816
# update: 9390/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 0.9763916730880737
# update: 9395/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.2008668184280396
# update: 9400/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 1.0708863735198975
# update: 9405/ 9765 Max reward: 77.75 Min reward: -2.25 Mean reward: 1.3521729707717896
# update: 9410/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9634156823158264
# update: 9415/ 9765 Max reward: 75.75 Min reward: -2.25 Mean reward: 0.8761963844299316
# update: 9420/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.1970337629318237
# update: 9425/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9389160871505737
# update: 9430/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 1.009973168373108
# update: 9435/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 1.1782715320587158
# update: 9440/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8289673924446106
# update: 9445/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.8740723133087158
# update: 9450/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.2316162586212158
# update: 9455/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9633057117462158
# update: 9460/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.3459718227386475
# update: 9465/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 1.3605713844299316
# update: 9470/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.0895752906799316
# update: 9475/ 9765 Max reward: 78.75 Min reward: -2.25 Mean reward: 0.7837647199630737
# update: 9480/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.1198853254318237
# update: 9485/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.0729615688323975
# update: 9490/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.1458008289337158
# update: 9495/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 1.2228515148162842
# update: 9500/ 9765 Max reward: 77.75 Min reward: -2.25 Mean reward: 1.1780152320861816
# update: 9505/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.3669679164886475
# update: 9510/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.2337769269943237
# update: 9515/ 9765 Max reward: 79.05000305175781 Min reward: -2.25 Mean reward: 1.1687989234924316
# update: 9520/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.2320313453674316
# update: 9525/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 1.1584961414337158
# update: 9530/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.0812623500823975
# update: 9535/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.0906007289886475
# update: 9540/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 1.0513428449630737
# update: 9545/ 9765 Max reward: 76.44999694824219 Min reward: -2.25 Mean reward: 1.13458251953125
# update: 9550/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.2641479969024658
# update: 9555/ 9765 Max reward: 77.75 Min reward: -2.25 Mean reward: 1.1416505575180054
# update: 9560/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9907227158546448
# update: 9565/ 9765 Max reward: 77.75 Min reward: -2.25 Mean reward: 1.1288574934005737
# update: 9570/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.0224366188049316
# update: 9575/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.0708740949630737
# update: 9580/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.0936157703399658
# update: 9585/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 1.0909912586212158
# update: 9590/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.2589356899261475
# update: 9595/ 9765 Max reward: 78.5999984741211 Min reward: -2.25 Mean reward: 1.0097535848617554
# update: 9600/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.22528076171875
# update: 9605/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.0926027297973633
# update: 9610/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 1.3260376453399658
# update: 9615/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.036596655845642
# update: 9620/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.9622315764427185
# update: 9625/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.0285890102386475
# update: 9630/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.0441651344299316
# update: 9635/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 1.0998048782348633
# update: 9640/ 9765 Max reward: 79.05000305175781 Min reward: -2.25 Mean reward: 1.03521728515625
# update: 9645/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.0564942359924316
# update: 9650/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.1376954317092896
# update: 9655/ 9765 Max reward: 77.44999694824219 Min reward: -2.25 Mean reward: 1.4041626453399658
# update: 9660/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.1161255836486816
# update: 9665/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.208740234375
# update: 9670/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 0.9898926019668579
# update: 9675/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.4032838344573975
# update: 9680/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.0480592250823975
# update: 9685/ 9765 Max reward: 76.9000015258789 Min reward: -2.25 Mean reward: 1.0861328840255737
# update: 9690/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.1480591297149658
# update: 9695/ 9765 Max reward: 78.05000305175781 Min reward: -2.25 Mean reward: 1.2561891078948975
# update: 9700/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.3286378383636475
# update: 9705/ 9765 Max reward: 79.9000015258789 Min reward: -2.25 Mean reward: 0.9787720441818237
# update: 9710/ 9765 Max reward: 77.05000305175781 Min reward: -2.25 Mean reward: 1.1246460676193237
# update: 9715/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 1.06298828125
# update: 9720/ 9765 Max reward: 79.05000305175781 Min reward: -2.25 Mean reward: 1.0476562976837158
# update: 9725/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 1.267736792564392
# update: 9730/ 9765 Max reward: 77.05000305175781 Min reward: -2.25 Mean reward: 1.35003662109375
# update: 9735/ 9765 Max reward: 77.05000305175781 Min reward: -2.25 Mean reward: 1.1174805164337158
# update: 9740/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.2514162063598633
# update: 9745/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.2511475086212158
# update: 9750/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.3040772676467896
# update: 9755/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 1.3241089582443237
# update: 9760/ 9765 Max reward: 77.9000015258789 Min reward: -2.25 Mean reward: 1.0984132289886475
# update: 9765/ 9765 Max reward: 80.05000305175781 Min reward: -2.25 Mean reward: 1.0265381336212158

# %%
env = ScheduleGym(num_days=2, num_hours=4, num_classes=1, num_subjects=2)

# %%
state, _ = env.reset()

# %%
env.render()
action, logprob, _, value = agent.get_action_and_value(torch.tensor(state, device=device, dtype=torch.float32).unsqueeze(0))
state, reward, done, info, _ = envs.step(action.cpu().numpy())
print(f'Action {action}')
print(f'Reward {reward}')
print(f'Done {done}')
# Out:
# Class 1:
# Day 1: [-1 -1 -1 -1]
# Day 2: [-1 -1 -1 -1]
#
# Fitness: -4.0, Actions left: 40
# Target Hours:
# Class 1: [3 1]

# %%
def visualize_agent(agent, env, n_episodes=5):
    for i_episode in range(1, n_episodes + 1):
        state, info = env.reset()
        done = False
        score = 0
        max_t = 256
        t = 0
        while not done:
            env.render()
            state = torch.FloatTensor(state).unsqueeze(0).to(device)
            #action = agent.choose_action(state)
            action, logprob, _, value = agent.get_action_and_value(state)
            action = action.squeeze().cpu().numpy()
            #action = action.cpu().numpy()
            next_state, reward, done, truncated, info = env.step(action)
            state = next_state
            score += reward
            t += 1
            if done or t >= max_t:
                break
        print(f"Episode {i_episode}\tScore: {score}")
    env.close()

# %%
env = gym.make(args.env_id, render_mode="human")
visualize_agent(agent, env)
# Out:
# Episode 1	Score: -256.0
# Episode 2	Score: -256.0
# Episode 3	Score: -256.0
# Episode 4	Score: -256.0
# Episode 5	Score: -256.0
